# %% [markdown]
# # Student Support Resources & Its Relationship with Standardized Testing for NYC Students From Grades 3 to 8

# %% [markdown]
# # Overview

# %% [markdown]
# The public school system in New York City has been facing immense scrutiny for its lackluster student performance. To substantiate whether these claims can be supported by public educational data, we sought out to measure the correlation between existing student support resources and student performance as defined by passing rates on annual statewide exams. Using the most recent data from the NYC Council, we created a metric score to assess the availability of student resources and regressed this score against student performance sectioned into quartiles based on the school’s overall economic need index. Ultimately, we found that the majority of resources did not show correlation with test performance, while the presence of art programs as well as gifted and talented programs showed minor correlation with higher test performance for schools in all economic situations. Interestingly however, a higher number of teachers and support staff did not correlate with higher student performance for schools in the lowest and highest quartiles, but did have a correlation for schools in the middle two quartiles.

# %% [markdown]
# # Names
#
# - Vince Wong
# - George Li
# - Han Nguyen
# - Matthew (Conrad) Sorenson
# - Carole Huang

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# Do additional in-school student support resources such as gyms, support staff, and art programs contribute to higher performance for students in grades 3-8 as measured by passing rates on statewide English and Math exams?
#
# - Furthermore, do specific support resources have a noticeable positive correlation with better test outcomes?

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# According to our background research, New York City’s public school system represents one of the most expansive and expensive educational programs in the United States, covering 2.6 million students and costing 34 billion annually as of 2020. On a per student basis, the city is spending 28,000 on each student, a record amount that exceeds second-place Boston’s \$ 22,000 by over 20 percent. However, the educational results of this spending has been relatively lackluster, as the system consistently produces less than 50\% proficiencies on English and Math state exams for students in grades 3-8. Specifically, in 2018 just 46.7 percent of students achieved proficient levels in English state exams and only 42.7 percent of students hit their marks in Math state exams.
#
# Prior research has been conducted over the past two decades on the deficiencies in NYC’s systematic approach toward funding education and has led to various reform efforts proposed by the city administration. As recent as 2014, Mayor Bill De Blasio implemented a new \$ 800 million plan called the ‘Renewal Program’ to invest in student support resources at low-performing schools in an effort to boost test performance. Over the years, the program seemed to show little signs of promise; 14 of the 94 schools receiving funding from the program had closed and student performance remained stagnant. Further, in 2018, The Educational Trust published a press release titled “Large New York school districts are not doing enough to prioritize resources to the schools with the greatest needs” describing the failure to provide the level of resources required by the highest-need schools. A similar report out of Democrat and Chronicle proclaimed “Education funding in New York inequitable, inadequate”, noting that resources were not being spent in the correct places–namely community development and tax adjustments for low-income districts.
#
# In juxtaposition to these pointed reports, however, a more neutral report published in The Washington Post acknowledged that expecting change after 3 years no matter how much money was infused into the schools was an unrealistic projection; real change takes time. Additionally, the program did demonstrate some positive direction, in that it considered in and out-of-school factors that affect learning, and connections between schools and communities. Nonetheless, the article noted that school resources have less of an impact on student achievement than out-of-school factors such as poverty. Policymakers have repeatedly overestimated their capacity to overcome factors such as housing insecurity, food insecurity, students’ parents’ employment insecurity and more by increasing investment on student support resources within the school network. To conclude, the article pointed to two possible realities for the education reform: ‘1. That education reform can be very helpful, if they’re the right ones and if we’re patient and committed; but 2. We as a society are deceiving ourselves if we think we’ll transform educational outcomes without addressing inequality.’
#
# Based on our team members’ prior work in educational services, we believe both to be true, but that the latter point is much closer to the truth of the situation. Neglecting to address racism, discrimination, concentrated poverty, disinvestment, and disparate access to a variety of resources while focusing primarily on school resource investment will fail to create the desired positive educational outcome for all student demographics.
#
# As a result of this widespread criticism from many educational experts and journalists, the Renewal Program was shuttered in 2019. Despite the lackluster results of this 4-year endeavor, De Blasio’s team announced an adjusted approach that remains committed to the same methodologies of investing in student support services at schools. Only now, any school is eligible, not just the schools identified as being low in performance.
#
# Our team fails to see how this “new” approach addresses the shortcomings of the previous approach as there is little to suggest that there will be a pivoted focus on underserved resources that were not developed by the Renewal Program. If the new program continues to neglect overarching community problems that heavily affect high-need students’ performance, then a logical assumption is that the outcomes will not be very different from the Renewal Program.
#
# Therefore, in our research, we wanted to look at the data provided by the city council to identify whether there is evidence that has influenced a continued commitment to this approach of investing in student support resources. Perhaps, an increase in student support resources has contributed to higher overall test performance and this information was unclear to the public. Further, if we do observe a measurable effect, we hope to identify specific resources that may have a positive relationship with higher student performance so as to provide a recommendation on how to better allocate school funding for potentially higher impact.
#
# References:
#
# 1) https://www.washingtonpost.com/education/2019/01/07/new-york-city-offers-some-unpleasant-truths-about-school-improvement/
#
# 2) https://ny.chalkbeat.org/2019/2/26/21106894/new-york-city-ends-controversial-renewal-turnaround-program-but-the-approach-is-here-to-stay
#
# 3) https://newyork.edtrust.org/press-release/equal-is-not-the-same-as-equitable-large-new-york-school-districts-are-not-doing-enough-to-prioritize-resources-to-the-schools-with-the-greatest-needs/
#
# 4) https://www.democratandchronicle.com/story/news/education/2020/02/17/usccr-new-york-education-funding-inequitable-inadequate-foundation-aid/4737790002/
#
# 5) https://nypost.com/2019/05/21/nyc-spends-double-the-national-average-on-education-has-little-to-show-for-it/
#
# 6) https://www.nytimes.com/2018/10/26/nyregion/deblasio-school-renewal-bill.html

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We believe that most in-school student support resources will not have a sizable correlation with student passing rate on annual statewide English and Math exams. Based on our prior research, in-school resources have seemingly little effect on student performance for those who are already behind. Rather, it is improvements for out-of-school experiences such as poverty and discrimination that will have a greater effect on test performance.
#
# However, we predict that the number of support staff as well as gifted and talented programs will stand out as resources that positively correlate with increased test performance. This is because we believe support staff as well as gifted and talented programs contribute to better community development, given they improve general outlooks of education for student families.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# * Dataset Name: NYC School Explorer Data (2018)
# * Link to the dataset: https://council.nyc.gov/data/school-explorer/
# * Number of observations: 836 data points with 224 features
#
# This dataset is provided by the NYC Council, with the original intent of providing NYC parents information on where to send their children to school. Included here are data about school characteristics such as admissions, budget, and economic need; types of resources such as gyms, auditoriums and libraries; and summaries of test performance for students in grades 3-8 in each school. The data has 224 variables for each of the 836 schools, along with both categorical and numerical values, so it will require cleaning for our analysis purposes.

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from statistics import median 
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('school_data.xlsx')
df.head()
# Out:
#   ATS System Code Location Code                   Location Name   BEDS Number  \
# 0          01M015          M015       P.S. 015 Roberto Clemente  310000000000
# 1          01M019          M019             P.S. 019 Asher Levy  310000000000
# 2          01M020          M020            P.S. 020 Anna Silver  310000000000
# 3          01M034          M034  P.S. 034 Franklin D. Roosevelt  310000000000
# 4          01M063          M063       The STAR Academy - P.S.63  310000000000
#
#   Managed By Name Location Type Description School Type  \
# 0             DOE          General Academic  Elementary
# 1             DOE          General Academic  Elementary
# 2             DOE          General Academic  Elementary
# 3             DOE          General Academic         K-8
# 4             DOE          General Academic  Elementary
#
#   Offers Kindergarten Classes Has A Pre-K                    Grades Offered  \
# 0                         YES         YES           PK,0K,01,02,03,04,05,SE
# ...

# %%
df.shape
# Out:
# (836, 224)

# %% [markdown]
# ### 836 schools, 224 features

# %% [markdown]
# # Data Cleaning
#
# Due to the large size and qualitative nature of the dataset, we performed extensive cleaning to prepare it for our analysis. First, we determined based on our intuition from background research the variables that could be relevant to our research. This reduced the dataframe to 39 columns from 224. Following this, we created a function to convert the binary categorical values of ‘yes’ and ‘no’ into numerical values of ‘1’ and ‘0’ to prepare it for sklearn. Then, we renamed the columns with longer descriptive titles to shorter titles to make it more convenient when we call the variables later. After this, we dropped the original columns to remove duplicates. Seeing as there were still categorical values for zoning rules and accessibility, we converted the respective values to a range of 0-2 and 0-3 respectively, with 0 being least accessible and 2-3 being most accessible. Again, we drop the duplicate columns after our conversation. At this stage, we noticed that there remained one more type of categorical value labeled ‘redacted for privacy concerns’. To address this, we converted those values to null. Then, after looking at the test scores, we noticed that we only had information about the percentage of students who passed a specific test, and the number of students passing, but no information about the percentage of total tests passed. Since we are using this variable to represent student performance in a school, we calculated this by creating an arithmetic function using the present variables. We assigned the passing percentage of total tests to a new column with the variable passtot. The final step for cleaning our general dataframe was removing special education schools and home schools from the list, leaving only general education schools. This is because we recognize that special education schools and home schools potentially have a different baseline of performance as well as resources, so we decided to only focus on general education schools because that represented the majority of schools. Further, this would remove the ability for special types of schools to skew our findings. Given more time, we may conduct another analysis on the other two types of schools. Following this step, our data was sufficiently cleaned for exploratory data analysis.

# %% [markdown]
# Binary function so that all categorical data (with 'yes' or 'no') is transformed into numerical data for sklearn.

# %%
def binary(x):
    x = x.lower()
    if x == 'yes':
        return 1
    else:
        return 0

# %% [markdown]
# Grab the columns that we are interested in.

# %%
gen = df[['Geographical District Code', 'Location Type Description', 'School Type', 'Grades Offered', 
           'Community District', 'Council District',
           'Number of 3rd Through 8th Grade Students Who Passed The State English Language Arts Exams',
          'Percentage of 3rd Through 8th Grade Students Who Passed The State English Language Arts Exams','Number of 3rd Through 8th Grade Students Who Passed The State Math Exam',
          'Percentage of 3rd Through 8th Grade Students Who Passed The State Math Exam', 'Does the School Have A Gifted And Talented Program',
          'Total Number of Removals and Suspensions', 'Is there a Gymnasium', 'Is the Gymnasium Shared With Other Schools',
          'Is the Gymnasium Used For Any Other Purpose Beside Physical Education','Does the School have an Auditorium',
          'Does the School have a Library', 'Total Number of Teachers, Administrators and Support Staff', 'Total Expense Budget',
          'PTA Funding', 'PTA Funding Per Student','Total Enrollment', 'Number of Students In Grade 3', 
          'Number of Students In Grade 4', 'Number of Students In Grade 5', 'Number of Students In Poverty', 'Percentage of  Students In Poverty',
        'Economic Need Index', 'Average Daily Breakfast Participation', 
          'Average Daily Lunch Participation', 'Number of Salad Bars', 'Elementary Admissions Methods',
          'Does the School have a Gifted and Talented Program in Kindergarten', 'Type of Dual Language Programs',
          'Number of Guidance Counselors', 'Number of Social Workers', 'Is the School Co Located', 'How Accessible is the School',
          'All Four Arts Disciplines Provided to Grades 1 through 5']]
gen
# Out:
#      Geographical District Code Location Type Description      School Type  \
# 0                             1          General Academic       Elementary
# 1                             1          General Academic       Elementary
# 2                             1          General Academic       Elementary
# 3                             1          General Academic              K-8
# 4                             1          General Academic       Elementary
# ..                          ...                       ...              ...
# 831                          12         Special Education  K-12 all grades
# 832                          10         Special Education  K-12 all grades
# 833                          12         Special Education              K-8
# 834                          10         Special Education              K-8
# 835                          11         Special Education  K-12 all grades
#
# ...

# %% [markdown]
# Here, we apply our binary function to columns with 'yes' (1) or 'no'  (0) data. This is neccessary as we will need to use these categorical variables for further calculation and analysis.
#
# We also rename the columns with shorter names for convenience.

# %%
gen['gifted_talented_program'] = gen['Does the School Have A Gifted And Talented Program'].apply(binary)
gen['gym'] = gen['Is there a Gymnasium'].apply(binary)
gen['shared_gym'] = gen['Is the Gymnasium Shared With Other Schools'].apply(binary)
gen['multiuse_gym'] = gen['Is the Gymnasium Used For Any Other Purpose Beside Physical Education'].apply(binary)
gen['colocated'] = gen['Is the School Co Located'].apply(binary)
gen['four_disciplines_1to5'] = gen['All Four Arts Disciplines Provided to Grades 1 through 5'].apply(binary)
gen['auditorium'] = gen['Does the School have an Auditorium'].apply(binary)
gen['library'] = gen['Does the School have a Library'].apply(binary)
gen['gifted_talent_kinder'] = gen['Does the School have a Gifted and Talented Program in Kindergarten'].apply(binary)

## Drop the original columns we applied the function on because we don't want duplicates.
drop_lst = ['Does the School Have A Gifted And Talented Program', 'Is there a Gymnasium', 'Is the Gymnasium Shared With Other Schools',
           'Is the Gymnasium Used For Any Other Purpose Beside Physical Education', 'Is the School Co Located',
           'All Four Arts Disciplines Provided to Grades 1 through 5', 'Does the School have an Auditorium',
           'Does the School have a Library','Does the School have a Gifted and Talented Program in Kindergarten','Grades Offered']
gen = gen.drop(columns=drop_lst)

# %%
gen.head()
# Out:
#    Geographical District Code Location Type Description School Type  \
# 0                           1          General Academic  Elementary
# 1                           1          General Academic  Elementary
# 2                           1          General Academic  Elementary
# 3                           1          General Academic         K-8
# 4                           1          General Academic  Elementary
#
#    Community District  Council District  \
# 0                 103                 2
# 1                 103                 2
# 2                 103                 1
# 3                 103                 2
# 4                 103                 2
#
#   Number of 3rd Through 8th Grade Students Who Passed The State English Language Arts Exams  \
# 0                                                 45
# 1                                                 51
# 2                                                 83
# 3                                                 57
# ...

# %% [markdown]
# We made two functions to encode some of the categorical variables. A data dictionary is commented out so that we remember which numbers represent which variables.

# %%
def access(x):
    if x=='Not Accessible':
        return 0
    if x=='Partially Accessible':
        return 1
    else:
        return 2
    
def zone(x):
    if x=='Zoned':
        return 0
    if x=='Non-Zoned':
        return 1
    if x=='Citywide G&T':
        return 2
    if x=='G&T Only':
        return 3
    else:
        return np.nan

# %%
#Apply the functions to appropriate columns.
gen['zoned'] = gen['Elementary Admissions Methods'].apply(zone)
gen['access'] = gen['How Accessible is the School'].apply(access)

#Drop duplicate columns.
gen = gen.drop(columns=['How Accessible is the School', 'Elementary Admissions Methods'])

# %% [markdown]
# We only want schools that are considered 'general academic' as special education schools may skew the data. If time permitted, we will analyze special education schools as their own entity.

# %%
gen = gen.loc[df['Location Type Description'] == 'General Academic']
gen = gen.loc[df['School Type'].isin(['Elementary','K-8','K-12 all grades'])]
gen.head()
# Out:
#    Geographical District Code Location Type Description School Type  \
# 0                           1          General Academic  Elementary
# 1                           1          General Academic  Elementary
# 2                           1          General Academic  Elementary
# 3                           1          General Academic         K-8
# 4                           1          General Academic  Elementary
#
#    Community District  Council District  \
# 0                 103                 2
# 1                 103                 2
# 2                 103                 1
# 3                 103                 2
# 4                 103                 2
#
#   Number of 3rd Through 8th Grade Students Who Passed The State English Language Arts Exams  \
# 0                                                 45
# 1                                                 51
# 2                                                 83
# 3                                                 57
# ...

# %% [markdown]
# ### We create a function to clear NaN data.
# This is necessary because we will need to include these variables for further calculation.

# %%
def clean_nans(x):
    if x=='No Data':
        return np.nan
    else:
        return float(x)

# %% [markdown]
# We are interested in finding the total passing rate (%) in ELA, Math, and in both as this is important for our assessment.

# %%
## Transform data into appropriate type.
gen['ela_passct']=gen['Number of 3rd Through 8th Grade Students Who Passed The State English Language Arts Exams'].apply(clean_nans)
gen['ela_passpct']=gen['Percentage of 3rd Through 8th Grade Students Who Passed The State English Language Arts Exams'].apply(clean_nans)
gen['math_passct']=gen['Number of 3rd Through 8th Grade Students Who Passed The State Math Exam'].apply(clean_nans)
gen['math_passpct']=gen['Percentage of 3rd Through 8th Grade Students Who Passed The State Math Exam'].apply(clean_nans)

## Drop duplicate columns.
gen = gen.drop(columns = ['Number of 3rd Through 8th Grade Students Who Passed The State English Language Arts Exams',
                         'Percentage of 3rd Through 8th Grade Students Who Passed The State English Language Arts Exams',
                         'Number of 3rd Through 8th Grade Students Who Passed The State Math Exam',
                         'Percentage of 3rd Through 8th Grade Students Who Passed The State Math Exam'])

# %%
gen.head()
# Out:
#    Geographical District Code Location Type Description School Type  \
# 0                           1          General Academic  Elementary
# 1                           1          General Academic  Elementary
# 2                           1          General Academic  Elementary
# 3                           1          General Academic         K-8
# 4                           1          General Academic  Elementary
#
#    Community District  Council District  \
# 0                 103                 2
# 1                 103                 2
# 2                 103                 1
# 3                 103                 2
# 4                 103                 2
#
#   Total Number of Removals and Suspensions  \
# 0            Redacted for privacy concerns
# 1            Redacted for privacy concerns
# 2            Redacted for privacy concerns
# 3                                       43
# 4                                       12
#
# ...

# %% [markdown]
# ### We also create a function to clean 'redacted for privacy concerns' to null.
# For ethics and privacy reason, we do not want to include data that is indicated as private.

# %%
def priv(x):
    if x=='Redacted for privacy concerns':
        return np.nan
    else:
        return x

# %%
## Apply priv() to the appropriate column.
gen['removals_suspension_ct'] = gen['Total Number of Removals and Suspensions'].apply(priv)

## Drop duplicate.
gen = gen.drop(columns=['Total Number of Removals and Suspensions'])

# %% [markdown]
# The data is now cleaned. We have left the nulls because we may or may not need them after further EDA. If the features prove to be non-consequential to our analysis, we will drop them for further clarity. If not, we can impute the null data with their respective means, medians, etc.

# %% [markdown]
# # Data Analysis & Results
#
# We began our exploratory data analysis by first calculating measures of central tendencies for variables we were interested in such as economic need index and total funding by district. Of particular note here was that higher budget correlated strongly with higher numbers of staff. This may point to the fact that a large portion of the budget was spent on human resources. Since this information is not easily accessible publicly, this provided a meaningful context of how the budget is distributed. Another tidbit that was interesting was that the data showed that the district with the highest economic need index did not receive the most funding. This information matches our background research in that school funding was prioritized by enrollment first, need second. However, we question whether this makes sense if additional resources aren’t also being allocated to invest in the community. To break this down further, we created scatterplots to visualize the economic need index of all schools against total budget and the economic need index of all schools against their students’ passing rates. What we found was that there was no correlation between ENI and budget, and a strong negative correlation between ENI and test performance. This further demonstrated that there was inequity in the distribution of resources based on need and highlighted that there may be different baselines of performance for different economic need classes. This information suggested that in our final analysis and presentation of findings that it may be beneficial to split up schools based on their economic need index. To complete our exploratory data analysis, we created additional graphs to visualize the relationships between certain variables to make sure that we didn’t miss anything by simply looking at the numbers without checking the distribution. To inspect the pattern of economic need index for all schools, we created a distribution plot graph which had a strong negative skew, indicating that a vast majority of schools had a high economic index. To get more specific, we checked the distribution of economic need indexes within each district by creating a boxplot graph. This graph showed that some districts had higher variance in economic need, but also further affirming that a large number of districts had high economic need index. This suggests that using economic need index to split schools into groups for analysis may lead to more accurate results. Additionally, we created visualizations for total enrollment, total staffing, number of social workers, numbers of students in poverty, and total expense budget, which all showed similar positive skew in their distributions, affirming that all these school characteristics may be tied to each other.
#
# For our final stretch, we first created a dataframe called resources that only included the student resources from the general dataframe. Then, we divided the schools in our resource dataframe into quartiles by economic index using the 25th percentile, 25th-50th percentile, 50th-75th percentile, and 75th-99th percentile. Then within each quartile, we converted the values of our non-binary variables into percentile values relative to the values of that variable within the quartile. Thirdly, we created a function to calculate a metric score for resources by weighting all the variables evenly. Finally, we generated a correlation plot for each quartile to see which resources had a positive correlation to school test performance(passtot). This correlation also shows the correlation of our resource metric against test performance.
#
# To further visualize our findings, we created scatterplots to show the top 3 resources that correlated with test performance for each quartile, as well as a scatterplot that showed the relationship between resource scores and test performance.
#
# A note: Although our metric used a non-scientific approach to determine the weights of the variables for our metric score, the concept of creating a metric is what we hope to emphasize here. In the future, we will look to use another set of data for student performance to determine weights so we can validly regress our metric against state test performance (total passing percentage).

# %% [markdown]
# ### First, we want to see the some of the central tendency (mean and median) of some features we are interested in.
#
# 1/ Economic Need Index

# %%
econ_need = pd.DataFrame(gen.groupby('Geographical District Code')['Economic Need Index'].mean())
econ_need
# Out:
#                             Economic Need Index
# Geographical District Code
# 1                                      0.701862
# 2                                      0.318410
# 3                                      0.512071
# 4                                      0.840677
# 5                                      0.883046
# 6                                      0.798668
# 7                                      0.932336
# 8                                      0.820556
# 9                                      0.941932
# 10                                     0.874319
# 11                                     0.743174
# 12                                     0.928099
# 13                                     0.709118
# 14                                     0.760765
# 15                                     0.529353
# 16                                     0.865782
# 17                                     0.802664
# 18                                     0.718862
# ...

# %%
print('District with highest economic need: District ' + str(econ_need['Economic Need Index'].idxmax()))
print('District with lowest economic need: District ' + str(econ_need['Economic Need Index'].idxmin()))
print('District average of economic need: ' + str(np.mean(econ_need['Economic Need Index'])))
print('District median of economic need: ' + str(median(econ_need['Economic Need Index'])))
# Out:
# District with highest economic need: District 9
# District with lowest economic need: District 2
# District average of economic need: 0.7305865011945405
# District median of economic need: 0.7375643599417901

# %% [markdown]
# 2/ Total Expense Budget

# %%
gen['Total Expense Budget'] = gen['Total Expense Budget'].apply(clean_nans)
budgets = pd.DataFrame(gen.groupby('Geographical District Code')['Total Expense Budget'].mean())
budgets
# Out:
#                             Total Expense Budget
# Geographical District Code
# 1                                   5.024653e+06
# 2                                   5.355608e+06
# 3                                   5.575139e+06
# 4                                   4.983656e+06
# 5                                   5.519147e+06
# 6                                   5.872606e+06
# 7                                   7.107841e+06
# 8                                   7.468749e+06
# 9                                   7.323630e+06
# 10                                  7.767553e+06
# 11                                  7.492097e+06
# 12                                  6.670007e+06
# 13                                  4.819297e+06
# 14                                  5.594271e+06
# 15                                  7.765947e+06
# 16                                  4.090521e+06
# 17                                  5.647165e+06
# 18                                  6.837108e+06
# ...

# %%
print('District with highest budget: District ' + str(budgets['Total Expense Budget'].idxmax()))
print('District with lowest budget: District ' + str(budgets['Total Expense Budget'].idxmin()))
print('District average of budget: ' + str(np.mean(budgets['Total Expense Budget'])))
print('District median of budget: ' + str(median(budgets['Total Expense Budget'])))
# Out:
# District with highest budget: District 24
# District with lowest budget: District 16
# District average of budget: 6574652.937737849
# District median of budget: 6636704.924908426

# %% [markdown]
# Notice that the district with highest economic need does not receive the most funding and vice versa. This indicates that funding could be distributed using other criterias besides economic needs.

# %% [markdown]
# 3/ Number of Social Workers

# %%
gen['Number of Social Workers'] = gen['Number of Social Workers'].apply(clean_nans)
sw = pd.DataFrame(gen.groupby('Geographical District Code')['Number of Social Workers'].mean())
sw
# Out:
#                             Number of Social Workers
# Geographical District Code
# 1                                           0.470588
# 2                                           0.833333
# 3                                           0.684211
# 4                                           1.055556
# 5                                           0.875000
# 6                                           0.884615
# 7                                           1.352941
# 8                                           1.000000
# 9                                           1.006071
# 10                                          1.152250
# 11                                          0.800000
# 12                                          1.227273
# 13                                          0.589474
# 14                                          0.757895
# 15                                          0.900000
# 16                                          0.571429
# ...

# %%
print('District with highest social workers: District ' + str(sw['Number of Social Workers'].idxmax()))
print('District with lowest social workers: District ' + str(sw['Number of Social Workers'].idxmin()))
print('District average of social workers: ' + str(np.mean(sw['Number of Social Workers'])))
print('District median of social workers: ' + str(median(sw['Number of Social Workers'])))
# Out:
# District with highest social workers: District 7
# District with lowest social workers: District 29
# District average of social workers: 0.766425868968951
# District median of social workers: 0.688259109311741

# %%
gen['Total Number of Teachers, Administrators and Support Staff'] = gen['Total Number of Teachers, Administrators and Support Staff'].apply(clean_nans)
sw = pd.DataFrame(gen.groupby('Geographical District Code')['Total Number of Teachers, Administrators and Support Staff'].mean())
sw
# Out:
#                             Total Number of Teachers, Administrators and Support Staff
# Geographical District Code
# 1                                                                   56.211765
# 2                                                                   58.836111
# 3                                                                   61.744737
# 4                                                                   56.470588
# 5                                                                   57.218750
# 6                                                                   61.211538
# 7                                                                   74.536471
# 8                                                                   78.590909
# 9                                                                   76.062857
# 10                                                                  80.524250
# 11                                                                  78.264516
# ...

# %%
print('District with highest number of teachers and staff: District ' + str(sw['Total Number of Teachers, Administrators and Support Staff'].idxmax()))
print('District with lowest number of teachers and staff: District ' + str(sw['Total Number of Teachers, Administrators and Support Staff'].idxmin()))
print('District average of teachers and staff: ' + str(np.mean(sw['Total Number of Teachers, Administrators and Support Staff'])))
print('District median of teachers and staff: ' + str(median(sw['Total Number of Teachers, Administrators and Support Staff'])))
# Out:
# District with highest number of teachers and staff: District 24
# District with lowest number of teachers and staff: District 16
# District average of teachers and staff: 70.44317925770693
# District median of teachers and staff: 70.17197802197802

# %% [markdown]
# Notice that district with highest budget has the most teachers and support staff and vice versa. This suggests that budget could directly link to human resources as our prediction. These trends are noted and will be considered in future analysis.

# %% [markdown]
# One thing to note is that we are also interested in the state testing passing rate as a measure of student performance, so we create another column called 'passtot' that stores the total passing rate (ELA & Math) of every school in the dataset.

# %%
## Calculate total number of staff.
gen['Total Staffing'] = gen['Total Number of Teachers, Administrators and Support Staff'] +  gen['Number of Social Workers']

## Calculate the total passing rate. 
## (Number of pass) / (Percent pass / 100) = Number of kids who took the test
gen['ela_testtot'] = round(gen['ela_passct']/(gen['ela_passpct']/100)) 
gen['math_testtot'] = round(gen['math_passct']/(gen['math_passpct']/100))
gen['passtot'] = round(((gen['ela_passct'] + gen['math_passct']) / (gen['ela_testtot']+gen['math_testtot']) * 100))

# %% [markdown]
# Above, we calculate the number of kids who took each test (ELA and MATH). Then, we divide this metric by the number of test administered to get the percent of kids who passed the state tests.

# %%
fig, axs = plt.subplots(1,2, figsize = (15,7))

axs[0].scatter(gen['Economic Need Index'], gen['Total Expense Budget'], color ='b')
axs[0].set_title('Economic Need Index vs \n Total Expense Budget')
axs[0].set_xlabel('Economic Need Index')
axs[0].set_ylabel('Total Expense Budget')

axs[1].scatter(gen['Economic Need Index'], gen['passtot'], color = 'orange')
axs[1].set_title('Economic Need Index vs \n State Testing Passing Percentage')
axs[1].set_xlabel('Economic Need Index')
axs[1].set_ylabel('Passing Percentage');

# %% [markdown]
# From this, we compared dataframes seeing if there was any visible patterns. Surprisingly, it appears that there is a negative correlation between the number of social workers and the passing rates of students. This may be because social workers work with a limited amount of students so their impact is masked behind the rest of the school population.

# %% [markdown]
# Before the analysis, we want to drop any nan values that may still be in the dataframe that could potentially raise errors.

# %%
gen.shape
# Out:
# (776, 42)

# %%
## We drop any left over nan values that clean_nan didn't catch.
gen.dropna(subset=['Number of Social Workers', 'Total Expense Budget', 'Total Staffing', 'passtot'], axis = 0, inplace=True)
gen.shape
# Out:
# (762, 42)

# %%
fig, axs = plt.subplots(1,1, figsize = (15,7))
axs.scatter(gen['Total Expense Budget'], gen['Total Staffing'], color ='b');
axs.set_title('Total Expense Budget vs Total Staffing', fontsize = 14)
axs.set_xlabel('Total Expense Budget', fontsize = 13)
axs.set_ylabel('Total Staffing', fontsize = 13);

# %% [markdown]
# This supports our prediction that budget positively correlates to human resources. I.e., the higher the budget, the more teachers, administrative and support staff, and social workers a school has.

# %%
fig, ax = plt.subplots(1,1, figsize=(20,15))
ax = sns.boxplot(x=gen['Geographical District Code'], y=gen['Economic Need Index'], data=gen)
ax.set_title('Economic Need Index Per School District', fontsize = 15)
ax.set_xlabel("Geographical District Code",fontsize=15)
ax.set_ylabel("Economic Need Index",fontsize=15);

# %% [markdown]
# In the scatter plot above, we can see the disparities of the economic need index of schools in comparison to other schools in their district.

# %%
sns.distplot(gen['Economic Need Index'])
plt.xlabel('Economic Need Index',fontsize=15)
plt.title('Distribution of Economic Need Index', fontsize =15);

# %% [markdown]
# Here, we see a strong negative skew, signaling that a majority of schools having a high ENI.

# %%
sns.distplot(gen['Total Enrollment'])
plt.xlabel('Total Enrollment', fontsize=13);
plt.title('Distribution of Total Enrollment', fontsize =15);

# %% [markdown]
# For enrollment, we're seeing that the distribution follows a positive skew. Schools have a median of a little over 500 students, however, we have some outliers with well over 1500+ students. This could be interesting later as we look at the resources allocated to schools.

# %%
sns.distplot(gen['Total Staffing'])
plt.xlabel('Total Staffing',size=15);
plt.title('Distribution of Total Staffing', fontsize =15);

# %% [markdown]
# Here, we're seeing that school staff numbers may have a relationship with enrollment numbers. It follows a similar positive skew. This is to be expected. More students = more teachers, social workers and guidance counselors. We will be probing deeper to see if social workers and guidance counselors follow the same distribution.

# %%
sns.distplot(gen['Number of Social Workers'])
plt.xlabel('Number of Social Workers', fontsize=15);
plt.title('Distribution of Social Workers', fontsize =15);

# %% [markdown]
# Here we see social workers seem to follow a similar distribution. It appears that higher student numbers lead to higher number of social workers. The question here is are they being allocated in the right places?

# %%
sns.distplot(gen['Number of Students In Poverty'])
plt.xlabel('Number of Students In Poverty', fontsize=15);
plt.title('Distribution of Students In Poverty', fontsize =15);

# %% [markdown]
# What we're seeing here in these above three graphs is that number of poverty students closely follows the distribution of student enrollment, many schools are comprised of a large proportion of students in poverty, and the economic need index reflects that information. It is striking that a significant portion of schools have an overwhelming student population experiencing poverty and high economic need, and yet many schools have only 1 social worker.

# %%
sns.distplot(gen['Total Expense Budget'])
plt.xlabel('Total Expense Budget',fontsize=15);
plt.title('Distribution of Total Expense Budget', fontsize =15);

# %% [markdown]
# Here again we see that expense budget follows the distribution of student enrollment. It is slightly positive skewed with median levels that line up with enrollment distribution.

# %% [markdown]
# ## Further Analysis - Creating resource data frame. Creating Metric Function. Splitting the schools into 4 percentiles based on economic need index--this will help reduce bias.

# %%
## Change continuous values into percentile.
gen['teachers_pct'] = gen['Total Number of Teachers, Administrators and Support Staff'].rank(pct=True)
gen['socialworkers_pct'] = gen['Number of Social Workers'].rank(pct=True)
gen['totalstaff_pct'] = gen['Total Staffing'].rank(pct=True)

## Calculate resource scores for every school.
gen['resource_scores'] = gen['teachers_pct'] + gen['socialworkers_pct'] + gen['gifted_talented_program'] + gen['gym'] + gen['shared_gym'] + gen['multiuse_gym']+ gen['colocated'] + gen['four_disciplines_1to5'] + gen['auditorium'] + gen['library'] + gen['gifted_talent_kinder']

# %%
resources = gen[['Economic Need Index','Total Number of Teachers, Administrators and Support Staff','Number of Social Workers','gifted_talented_program','gym','shared_gym','multiuse_gym','four_disciplines_1to5','auditorium','library','gifted_talent_kinder', 'teachers_pct' ,'socialworkers_pct', 'totalstaff_pct', 'resource_scores', 'passtot']]

# %%
econ_need['Economic Need Index'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    0.638535
# 0.50    0.737564
# 0.75    0.867916
# Name: Economic Need Index, dtype: float64

# %%
q1 = gen[gen['Economic Need Index'] <= 0.638535]
q2 = gen[(gen['Economic Need Index'] > 0.638535) & (gen['Economic Need Index'] <= 0.737564)]
q3 = gen[(gen['Economic Need Index'] > 0.737564) & (gen['Economic Need Index'] <= 0.867916)]
q4 = gen[gen['Economic Need Index'] > 0.867916]

# %%
q1r = resources[resources['Economic Need Index'] <= 0.638535]
q2r = resources[(resources['Economic Need Index'] > 0.638535) & (resources['Economic Need Index'] <= 0.737564)]
q3r = resources[(resources['Economic Need Index'] > 0.737564) & (resources['Economic Need Index'] <= 0.867916)]
q4r = resources[resources['Economic Need Index'] > 0.867916]

# %% [markdown]
# ## Analysis on 25th percentile

# %%
q1.head()
print(q1.shape)
# Out:
# (231, 46)

# %%
q1r.corr()[['passtot']]
# Out:
#                                                      passtot
# Economic Need Index                                -0.698483
# Total Number of Teachers, Administrators and Su... -0.124073
# Number of Social Workers                           -0.025789
# gifted_talented_program                             0.174066
# gym                                                 0.034492
# shared_gym                                          0.001308
# multiuse_gym                                             NaN
# four_disciplines_1to5                               0.118651
# auditorium                                          0.012726
# library                                            -0.138879
# gifted_talent_kinder                                0.206952
# teachers_pct                                       -0.135647
# socialworkers_pct                                  -0.015843
# totalstaff_pct                                     -0.133164
# ...

# %%
q1corr = q1.corr()
q1corr[['passtot']]
fig, axs = plt.subplots(ncols=3, figsize = (40,15))
print(' \033[1m                   Top 3 Resources for Schools in the 1st to 25th Percentile of Economic Need Index'+"\n")
axs[0].scatter(q1['four_disciplines_1to5'], q1['passtot'], color ='b')
axs[0].scatter(q1['gifted_talent_kinder'], q1['passtot'], color ='b')
axs[0].set_title('Presence of Gifted \n Talent Kindergarden Program vs \n Testing Passing Percentage', fontsize = 28)
axs[0].set_xlabel('Presence of Gifted Talent Kindergarden Program', fontsize = 28)
axs[0].set_ylabel('Testing Passing Percentage', fontsize = 28)
axs[1].scatter(q1['gifted_talented_program'], q1['passtot'], color = 'orange');
axs[1].set_title('Presence of Gifted \n Talent Program vs \n Testing Passing Percentage', fontsize = 28)
axs[1].set_xlabel('Presence of Gifted Talent Program', fontsize = 28)
axs[1].set_ylabel('Testing Passing Percentage', fontsize = 28)
axs[2].scatter(q1['four_disciplines_1to5'], q1['passtot'], color = 'red');
axs[2].set_title('All Four Disciplines of Arts \n vs \n Testing Passing Percentage', fontsize = 28)
axs[2].set_xlabel('All Four Disciplines', fontsize = 28)
axs[2].set_ylabel('Testing Passing Percentage', fontsize = 28);
# Out:
#                     Top 3 Resources for Schools in the 1st to 25th Percentile of Economic Need Index

# %% [markdown]
# For schools in the 1st to 25th percentile, the top three resources are:
# * Presence of Gifted &  Talented Kindergarden Programs
# * Presence of Gifted & Talented Programs
# * Availability of all 4 art disciplines from Grades 1 to 5 (dance, theater, visual arts, and music)

# %%
q1.dropna(inplace=True)

m, b = np.polyfit(q1['resource_scores'], q1['passtot'],1)

plt.figure(figsize=(7,5))
plt.scatter(q1['resource_scores'], q1['passtot'], color ='b')
plt.plot(q1['resource_scores'], m*q1['resource_scores'] + b, color ='r')
plt.title('Resource Scores vs State Testing Passing Percentage (Quartile 1)')
plt.xlabel('Resource Scores')
plt.ylabel('Passing Percentage');

# %%
q1r[['resource_scores', 'passtot']].corr()
# Out:
#                  resource_scores   passtot
# resource_scores         1.000000  0.065007
# passtot                 0.065007  1.000000

# %% [markdown]
# The graph above shows a very minimal relationship (r = .08) between resources and state testing passing percentage for students in schools in the first quartile. We will see a similar pattern for the other quartiles as well.

# %% [markdown]
# ## Analysis on 25th to 50th percentile

# %%
q2.head()
print(q2.shape)
# Out:
# (98, 46)

# %%
q2r.corr()[['passtot']]
# Out:
#                                                      passtot
# Economic Need Index                                -0.234934
# Total Number of Teachers, Administrators and Su...  0.279801
# Number of Social Workers                           -0.039285
# gifted_talented_program                             0.131134
# gym                                                -0.045825
# shared_gym                                         -0.048444
# multiuse_gym                                             NaN
# four_disciplines_1to5                               0.227098
# auditorium                                          0.038827
# library                                            -0.208348
# gifted_talent_kinder                                0.105421
# teachers_pct                                        0.290852
# socialworkers_pct                                  -0.048463
# totalstaff_pct                                      0.289434
# ...

# %%
q2corr = q2.corr()
q2corr[['passtot']]
fig, axs = plt.subplots(ncols=3, figsize = (40,15))
print(' \033[1m                   Top 3 Resources for Schools in the 26th to 50th Percentile of Economic Need Index'+"\n")
axs[0].scatter(q2['four_disciplines_1to5'], q2['passtot'], color ='b')
axs[0].scatter(q2['Total Expense Budget'], q2['passtot'], color ='b')
axs[0].set_title('Total Expense Budget vs \n Testing Passing Percentage', fontsize = 28)
axs[0].set_xlabel('Total Expense Budget', fontsize = 28)
axs[0].set_ylabel('Testing Passing Percentage', fontsize = 28)

axs[1].scatter(q2['Total Staffing'], q2['passtot'], color = 'orange');
axs[1].set_title('Total Staffing vs \n Testing Passing Percentage', fontsize = 28)
axs[1].set_xlabel('Total Staffing', fontsize = 28)
axs[1].set_ylabel('Testing Passing Percentage', fontsize = 28)
axs[2].scatter(q2['four_disciplines_1to5'], q2['passtot'], color = 'red')

axs[2].set_title('All Four Disciplines of Arts \n vs \n Testing Passing Percentage', fontsize = 28)
axs[2].set_xlabel('All Four Disciplines', fontsize = 28)
axs[2].set_ylabel('Testing Passing Percentage', fontsize = 28);
# Out:
#                     Top 3 Resources for Schools in the 26th to 50th Percentile of Economic Need Index

# %% [markdown]
# For schools in the 26st to 50th percentile, the top three resources are:
# * Total Expense Budget
# * Total Staffing
# * Availability of all 4 art disciplines from Grades 1 to 5 (dance, theater, visual arts, and music)

# %%
q2.dropna(inplace=True)

m, b = np.polyfit(q2['resource_scores'], q2['passtot'], 1)

plt.figure(figsize=(7,5))
plt.scatter(q2['resource_scores'], q2['passtot'], color ='b')
plt.plot(q2['resource_scores'], m*q2['resource_scores'] + b, color ='r')
plt.title('Resource Scores vs State Testing Passing Percentage (Quartile 2)')
plt.xlabel('Resource Scores')
plt.ylabel('Passing Percentage');

# %%
q2r[['resource_scores', 'passtot']].corr()
# Out:
#                  resource_scores   passtot
# resource_scores         1.000000  0.053084
# passtot                 0.053084  1.000000

# %% [markdown]
# ## Analysis on 50th to 75th percentile

# %%
q3.head()
print(q3.shape)
# Out:
# (163, 46)

# %%
q3r.corr()[['passtot']]
# Out:
#                                                      passtot
# Economic Need Index                                -0.285990
# Total Number of Teachers, Administrators and Su...  0.123158
# Number of Social Workers                           -0.134063
# gifted_talented_program                             0.214913
# gym                                                -0.056864
# shared_gym                                         -0.171630
# multiuse_gym                                             NaN
# four_disciplines_1to5                               0.215361
# auditorium                                          0.000613
# library                                            -0.049569
# gifted_talent_kinder                                0.091942
# teachers_pct                                        0.113083
# socialworkers_pct                                  -0.124008
# totalstaff_pct                                      0.111216
# ...

# %%
q3corr = q3.corr()
q3corr[['passtot']]
fig, axs = plt.subplots(ncols=3, figsize = (40,15))
print(' \033[1m                   Top 3 Resources for Schools in the 51th to 75th Percentile of Economic Need Index'+"\n")
axs[0].scatter(q4['four_disciplines_1to5'], q4['passtot'], color ='b')
axs[0].scatter(q3['four_disciplines_1to5'], q3['passtot'], color ='b')
axs[0].set_title('All Four Disciplines of Arts \n vs \n Testing Passing Percentage', fontsize = 28)
axs[0].set_xlabel('All Four Disciplines', fontsize = 28)
axs[0].set_ylabel('Testing Passing Percentage', fontsize = 28);

axs[1].scatter(q3['gifted_talented_program'], q3['passtot'], color = 'orange');
axs[1].set_title('Presence of Gifted \n Talent Program vs \n Testing Passing Percentage', fontsize = 28)
axs[1].set_xlabel('Presence of Gifted Talent Program', fontsize = 28)
axs[1].set_ylabel('Testing Passing Percentage', fontsize = 28)

axs[2].scatter(q3['Total Expense Budget'], q3['passtot'], color = 'red');
axs[2].set_title('Total Expense Budget vs \n Testing Passing Percentage', fontsize = 28)
axs[2].set_xlabel('Total Expense Budget', fontsize = 28)
axs[2].set_ylabel('Testing Passing Percentage', fontsize = 28);
# Out:
#                     Top 3 Resources for Schools in the 51th to 75th Percentile of Economic Need Index

# %% [markdown]
# For schools in the 51st to 75th percentile, the top three resources are:
# * Availability of all 4 art disciplines from Grades 1 to 5 (dance, theater, visual arts, and music)
# * Presence of Gifted & Talented Programs
# * Total Expense Budget

# %%
q3.dropna(inplace=True)

m, b = np.polyfit(q3['resource_scores'], q3['passtot'], 1)

plt.figure(figsize=(7,5))
plt.scatter(q3['resource_scores'], q3['passtot'], color ='b')
plt.plot(q3['resource_scores'], m*q3['resource_scores'] + b, color ='r')
plt.title('Resource Scores vs State Testing Passing Percentage (Quartile 3)')
plt.xlabel('Resource Scores')
plt.ylabel('Passing Percentage');

# %%
q3r[['resource_scores', 'passtot']].corr()
# Out:
#                  resource_scores   passtot
# resource_scores         1.000000 -0.003398
# passtot                -0.003398  1.000000

# %% [markdown]
# ## Analysis on 75th to 99th percentile

# %%
q4.head()
print(q4.shape)
# Out:
# (270, 46)

# %%
q4r.corr()[['passtot']]
# Out:
#                                                      passtot
# Economic Need Index                                -0.264044
# Total Number of Teachers, Administrators and Su...  0.051171
# Number of Social Workers                           -0.151937
# gifted_talented_program                             0.120872
# gym                                                -0.024887
# shared_gym                                         -0.009811
# multiuse_gym                                             NaN
# four_disciplines_1to5                               0.116454
# auditorium                                         -0.088678
# library                                             0.020043
# gifted_talent_kinder                                0.125565
# teachers_pct                                        0.033635
# socialworkers_pct                                  -0.136025
# totalstaff_pct                                      0.029870
# ...

# %%
q4corr = q4.corr()
q4corr[['passtot']]
fig, axs = plt.subplots(ncols=3, figsize = (40,15))
print(' \033[1m                   Top 3 Resources for Schools in the 76th to 99th Percentile of Economic Need Index'+"\n")
axs[0].scatter(q4['four_disciplines_1to5'], q4['passtot'], color ='b')
axs[0].set_title('All Four Disciplines of Arts \n vs \n Testing Passing Percentage', fontsize = 28)
axs[0].set_xlabel('All Four Disciplines', fontsize = 28)
axs[0].set_ylabel('Testing Passing Percentage', fontsize = 28);

axs[1].scatter(q4['gifted_talent_kinder'], q4['passtot'], color = 'orange');
axs[1].set_title('Presence of Gifted \n Talent Kindergarten Program vs \n Testing Passing Percentage', fontsize = 28)
axs[1].set_xlabel('Presence of Gifted Talent Program', fontsize = 28)
axs[1].set_ylabel('Testing Passing Percentage', fontsize = 28)

axs[2].scatter(q4['gifted_talented_program'], q4['passtot'], color = 'red');
axs[2].set_title('Presence of Gifted \n Talent Program vs \n Testing Passing Percentage', fontsize = 28)
axs[2].set_xlabel('Presence of Gifted Talent Program', fontsize = 28)
axs[2].set_ylabel('Testing Passing Percentage', fontsize = 28);
# Out:
#                     Top 3 Amentities for Schools in the 76th to 99th Percentile of Economic Need Index

# %% [markdown]
# For schools in the 76st to 99th percentile, the top three resources are:
# * Availability of all 4 art disciplines from Grades 1 to 5 (dance, theater, visual arts, and music)
# * Presence of Gifted & Talented Kindergarten Programs
# * Presence of Gifted & Talented Programs

# %%
q4.dropna(inplace=True)

m, b = np.polyfit(q4['resource_scores'], q4['passtot'], 1)

plt.figure(figsize=(7,5))
plt.scatter(q4['resource_scores'], q4['passtot'], color ='b')
plt.plot(q4['resource_scores'], m*q4['resource_scores'] + b, color ='r')
plt.title('Resource Scores vs State Testing Passing Percentage (Quartile 4)')
plt.xlabel('Resource Scores')
plt.ylabel('Passing Percentage');

# %%
q4r[['resource_scores', 'passtot']].corr()
# Out:
#                  resource_scores   passtot
# resource_scores         1.000000  0.021868
# passtot                 0.021868  1.000000

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# ### Question:
# The question we posed might run into some ethical concerns as our findings could influence educational policy and affect the work of school staff in NYC. Depending on which way our results sway, the administration could use the analysis to neglect existing educational inequities or defund programs that affect staff employment and quality of work.
#
# ### School Explorer Data:
# Though this data was reported by the NYC City Council, it is possible that they have already removed data or only put forth what they deem necessary. As stated on the website there are roughly 1.1million students in various NYC districts but the data provided only accounts for roughly half that many. Also, during our data cleaning process, we neglected special needs schools in favor of general education schools. These schools may have been the receipients of additional funding and potentially demonstrated a strong correlation between resources and test performance.
#
# As all of the data used is public access on the NYC Council website and not related to any individual, the school explorer data does not pose any privacy concerns.
#
# ### Biases for Data:
# One possbility could be that some schools that are underresourced do not have the ability to report the same depth of data, removing them from consideration and biasing the dataset. Another possibility is that schools count staff that fulfill multiple role in different categories. Furthermore, it's possible that certain student support resources were not recorded in this dataset. These factors can all bias our data and affect the completeness of data as well as the comprehensiveness of our analysis.
#
# ### Biases for Analysis:
# Some of our team members have vested interest in community programs for educational support in NYC. This internal bias may affect the interpretation of the data, however team members committed to be as objective as possible.
#
# ### Analysis
#
# While our analysis will not include any personally identifable information, concrete conclusions, or recommendations, our discussion of budgets and allocation of spending could be used for ulterior motives. A potential issue we forsee is the possibility of adminstrations or districts manipulating the criteria for student support resources in an effort to adjust our algorithm for suggesting additional funding. Furthermore, a nefarious organization may use our findings to suggest defunding schools, which we don't believe is a valid conclusion to draw from our findings.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# After exploring the data and analyzing the relationship between student support resources and test performance for each quartile of schools separated by economic need index, we concluded that overall, student support resources had a very small relationship with student performance.
#
# Across the quartiles of schools, the correlation between our resource metric and test performance ranged from -0.03 to 0.065. This signals that student support resources as measured by our metric does not correlate strongly with higher test performance.
#
# We did observe a pattern amongst the resources that had the highest correlation with test performance. Across all four quartiles, the presence of art programs spanning four disciplines(dance, visual arts, theater, and music), kindergarten gifted and talented programs, and general gifted and talented programs all had a measurable positive correlation with test performance. An interesting point to note is that for the middle two quartiles, the amount of total staff had a measurable positive correlation with test performance, however for the bottom and top quartiles, the amount of total staff had near no correlation.
#
# The takeaway from this research is that on a high level, the availibility of in-school student support resources are not significantly correlated with higher student test performance.
#
# This may suggest that resources are either not built sufficiently for the demographics they’re serving or that in-school resources cannot mitigate the effects of out-of-school factors. Further, our analysis suggests that the current utiliziation of funding for developing student support resources has potentially been ineffective.
#
# In all, our research suggests that the new approach taken by NYC Mayor Bill De Blasio to fund additional in-school student support resources may require additional consideration. Harking back to our background research, it may be more important to allocate those resources to fund community development to address out-of-school factors that are negatively affecting test performance for students in districts of highest need.

# %% [markdown]
# # Team Contributions

# %% [markdown]
# * Vince Wong - data cleaning, EDA, data visualizations, wrote descriptions for code
# * George Li - data cleaning, EDA, data visualizations; wrote summary descriptions for all sections; recorded video
# * Conrad Sorenson-contributed to ethics & privacy, data cleaning, EDA
# * Carole Huang - data visualizations, domain research
# * Han Nguyen - EDA, data cleaning, data visualization.
