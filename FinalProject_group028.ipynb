# %% [markdown]
# # Sentiment Analysis of COVID-19 on Twitter

# %% [markdown]
# # Overview

# %% [markdown]
# Our team is interested in analyzing how certain events that have occurred over the course of the COVID-19 pandemic have affected the way in which people perceive and thus react to said events in a sentimental and emotionally charged manner, particularly in the context of social media usage. Our analysis is not only limited to measuring the sentiment of tweets through a polarity scale, but we also measure variables such as language, ngrams, tweet_length, favorite and retweets, followers and statuses, and hashtag usage. For our analysis, we specifically set out to determine how people’s reaction to certain events on twitter circulates through different types of tweets, and have found although time did not appear to be a significant predictor, the sentiment of tweets did become generally more negative over the course of the pandemic. However, when associated with a specifically positive event, the sentiment of tweets was still similar to the overall sentiment of the dataset. We did find significant differences in the sentiment of tweets when filtered through specific languages.

# %% [markdown]
# # Names
#
# - Ming Qiu
# - Rachel Semaya
# - Shuyuan Shi
# - Matthew Sao
# - Brian Sanders

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# How has the sentiment of tweets been impacted and changed over the course of the COVID-19 pandemic when factoring in highly significant events that took place, specifically the emergence and approval of the COVID-19 vaccine, and language differences?

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# The outbreak of the COVID-19 pandemic has largely influenced people's lives in many different ways. Its prevalence has not only led to wide scale detriment in human life, but has presented us with unparalleled challenges in the social, economic and political sphere in which certain crises such as public policy, employment and labor, and the nature of healthy and safe work, converge. The dimension of behavior in which we learn and interact as humans have slowly become redefined into a more virtual environment in both personal and professional settings. Specifically, the guidelines of social isolation and distancing has imposed an immense impact on people's mental health and well-being. In a survey conducted by the Cleveland Clinic, around 74% of respondents in the 18-34 year old age bracket have been reported to experiencing mental health issues since the start of the pandemic, with the four most common issues being stress, anxiety, depression and loneliness or isolation (Gilmerm, 2020). Thus, we deemed it important to assess and monitor people's mental state throughout the pandemic and subsequent events to better inform our proposed analysis of how it affects the types of rhetoric being circulated throughout the media.
#
# The use of social media has been on the rise over this past decade, reflecting the rapid need to adapt to new technological platforms in order to access new information and connect with others. Social media platforms such as Twitter are a great resource to understanding how humans use these sites as a public and personal outlet to publish opinions and express emotions about the world around them. It has been widely used even before the onset of the pandemic, with an estimated 330 million monthly active users in 2019 (Ortiz-Ospina, 2019). Previous research suggests that tapping into the world of social media might be an ideal data source to infer the wellbeing of people's mental state, especially during this period (Yin, Yang & Li, 2021). And this data might be best utilized from Twitter, which according to Mansoor et. al (2020), has shown a significant increase (in tweets) relating to and reflecting the general emotions surrounding the novel coronavirus pandemic. Therefore, in hopes of gaining a glimpse into how people's mental state ultimately impacts the sentiment reflected on Twitter, we will pull data from the site’s API and analyze tweets by comparing the rhetoric of those that began to circulate at the start of the pandemic and those that circulated during significant events throughout the pandemic.
#
# In order to understand the cross-dimensional nature of human behavior and its changing ways during the pandemic and its perpetuated representation on social media, research was conducted in analyzing twitter sentiments over the course of the COVID-19 pandemic during its emergence starting in January and peaking in April (Luo, 2020). Although tweets relating to the topic of COVID-19 in China had the most negative sentiment in the spring, overall, it was found that tweets relating to the development of the coronavirus pandemic, specifically those that were considered major keywords in news coverage revealed an upward trend in positive sentiment. Research conducted by Mansoor et al., also investigates the sentiment of tweets, but until June (2020). Additionally, the analysis is done on a more global scale, with a focus on different countries that were hit worse relative to others during the pandemic such as the US, Brazil and India. It was found that when analyzing tweets, specifically those that were associated with “coronavirus”, “work from home”, and “online learning”, the sentiment was generally more positive than it was negative. Although our research question also delves into analyzing twitter sentiments relating to the pandemic and how its changed over time, a significant amount of the research we found does so, but in a way that abruptly ends in the summer of 2020. Additionally, results relating to sentiment analysis shown on a global-scale reveals varying sentiment in different countries, but fails to introduce any cross-linguistic differences within the analysis. According to Babbel Magazine, the two most spoken languages in the US are English and Spanish, with 245 million and 43.2 million native speakers respectively (Lyons, 2020). Therefore, based on these conclusions, we questioned whether analyzing the sentiment of tweets in the US should be considered within a cross-linguistic approach. Taking these prior conditions into consideration, our project and analysis will differ in that the data we plan to analyze will not only include tweets throughout the entirety of the pandemic, but will span events that have occurred in 2021, such as the emergence and approval of the COVID-19 vaccine in early December and continuing into the new year (Brothers, 2020). We believe that salient events such as this one, have had an effect on the type of tweets posted and circulated throughout the social media network. Within a cross-linguistic approach, we also believe that there will be a significant influence on the sentiment of tweets when reacting to said salient events.
#
# References (include links):
# 1. Brothers, W. (2020, December 03). A Timeline of COVID-19 Vaccine Development. Retrieved
# 	January 28, 2021, from
# 	https://www.biospace.com/article/a-timeline-of-covid-19-vaccine-development/
# 2. Gilmerm. (2020, September 25). Here's how the coronavirus pandemic has changed our lives.
# 	Retrieved March 14, 2021, from
# 	https://health.clevelandclinic.org/heres-how-the-coronavirus-pandemic-
# 	has-changed-our-lives/
# 3. Luo, N. (2020, May 08). Twitter Sentiment Analysis Based on News Topics during COVID-19.
# 	Retrieved January 28, 2021, from
# 	https://towardsdatascience.com/twitter-sentiment-analysis-based-on-news-
# 	Topics-during-covid-19-c3d738005b55
# 4. Lyons, D. (2020, May 18). What are the most spoken languages in The U.S.? Retrieved March
# 	14, 2021, from https://www.babbel.com/en/magazine/most-spoken-languages-in-the-us
# 5. Mansoor, M., Gurumurthy, K., R U, A., & Badri Prasad, V. (2020). Global Sentiment Analysis Of
# 	COVID-19 Tweets Over Time. https://arxiv.org/pdf/2010.14234.pdf
# 6. Ortiz-Ospina, E. (2019, September 18). The rise of social media. Retrieved March 14, 2021,
# 	from https://ourworldindata.org/rise-of-social-media
# 7. Yin, H., Yang, S., & Li, J. (2021). Detecting Topic and Sentiment Dynamics Due to
# 	COVID-19 Pandemic Using Social Media. International Conference on Advanced
# 	Data Mining and Applications, 610-623.
# 	https://link.springer.com/chapter/10.1007/978-3-030-65390-3_4

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We hypothesize that the sentiment of tweets became more negative over the course of the pandemic. We believe that as the pandemic continued to worsen and people spent more time on social media in isolation, pandemic fatigue set in and tweets became more negative over time, regardless of linguistic differences. However, when assessing the emergence and approval of the COVID-19 vaccine, we believe this to be a positive event that will affect the sentiment of tweets during the pandemic causing spikes in positive sentiment.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - Dataset Name: tweets.json
# - Link to the dataset: https://drive.google.com/file/d/1bvgTleOuBpJJ6L1iKMtMXPMDYuLjdZtF/view?usp=sharing
# - Number of observations: 77,651
#
# JSON file containing Tweet objects retrieved from the Twitter API using twarc. Tweet IDs were obtained from the Panacea Lab. The Panacea Lab has been collecting tweet IDs relating to the coronavirus pandemic since the emergence of COVID-19 in the United States around March of 2020. The lab specifically collects tweets that contain certain keywords and hashtags such as #coronavirus and #covid19. We then pass this dataset through an API to obtain the sentiment of our tweets and conduct our analysis with this dataset. More information on our data pipeline and how we obtained the sentiment for our tweets are detailed below.

# %% [markdown]
# # Setup

# %% [markdown]
# To save time, and not make un-neccesary api calls you can obtain the cleaned data through this google drive: https://drive.google.com/file/d/1sO5bR1-hvyLBDWj37nAzIpYIe_ZG1Gie/view?usp=sharing

# %%
import pandas as pd
import numpy as np
import os
import json
from pandas.io.json import json_normalize
from langdetect import detect
from langdetect import detect_langs
import re

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt

import seaborn as sns
sns.set()
sns.set_context('talk')

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

import nltk
import collections
from collections import Counter
from nltk.corpus import stopwords

import preprocessor.api as p
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
import re, nltk

import requests
import datetime
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

desiredColumns = [
        'created_at',
        'id',
        'full_text',
        'display_text_range',
        'entities',
        'user',
        'geo',
        'date',
        'coordinates',
        'place',
        'is_quote_status',
        'retweet_count',
        'favorite_count',
        'favorited',
        'retweeted',
        'lang',
        'quoted_status',
        'extended_entities',
        'withheld_copyright'
    ]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Data Collection Pipeline Explanation
#
# The function get_tweet_ids takes in a file containing dates in the format of YYYY-MM-DD. The function then loops through all the dates and downloads the tweet IDs the Panacea Lab collected for that day. It then randomly selects 300 tweets without replacement and stores the IDs in a list. The file that is downloaded from the lab is then deleted. This process repeats for all 307 days we are interested in analyzing. At the end of the function, the tweet IDs are written into a txt file to easily pass it in to twarc.
#
# The function rehydrate takes in a txt file containing the tweet IDs we wish to rehydrate. The txt file we saved from the previous function is passed in and the tweets are rehydrated and saved in a json file. This is done through twarc which calls on Twitter's API. The json file contains Tweet objects, which the documentation for can be found here, https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/tweet.

# %%
#Function to get tweet ids we wish to analyze and save it in a txt file
#Takes a while to run 10-15 mins
def get_tweet_ids(dates_file):
    
    #Opens the text file of dates that we wish to analyze
    #307 dates 
    text_file = open(dates_file, "r")
    dates = text_file.read().splitlines()
    text_file.close()
    
    #Should contain around 90,000 tweet IDs at the end
    ids_to_hydrate = []
    
    for i in range(len(dates)):
        
        current_date = dates[i]
        repo_link = "https://github.com/thepanacealab/covid19_twitter/raw/master/dailies/" + current_date + "/" + current_date + "_clean-dataset.tsv.gz"
        file_name = current_date + "_clean-dataset.tsv.gz"
        unzipped_file = current_date + "_clean-dataset.tsv"
        
        os.system("wget " + repo_link) #Get file from the Panacea Lab's repo
        os.system("gzip -d " + file_name) # Extract desired file and unzip it
        
        #Read in the tsv file containing the tweet IDs
        tweet_ids = pd.read_csv(unzipped_file, delimiter="\t")
        
        #Select the 300 tweets we wish to analyze for the current date
        #Stores it in a list that we append to our combined list of tweet ids
        one_day = list(tweet_ids['tweet_id'].sample(n=300, replace=False).values)
        ids_to_hydrate = ids_to_hydrate + one_day
        
        #Removes the tsv file after we're done sampling to reduce clutter
        os.remove(unzipped_file)
     
    #Writes the resulting list of 90,000 tweets to a txt file so we can use twarc to rehydrate these tweets
    with open("ids.txt", mode="w") as output_file:
        for ids in ids_to_hydrate:
            output_file.write("%s\n" % ids)
        
    return ids_to_hydrate

# %%
#Rehydrates our tweet ids into json data, takes in the file that is saved from get_tweet_ids
#Takes about 20 minutes to rehydrate 90,000 tweets
def rehydrate(tweet_ids):
    #Calls on twarc
    os.system("twarc hydrate " + tweet_ids + " > tweets.json")

# %% [markdown]
# Tidy Data Format - json
# - We receive our data in a .json format, which is a tidy data format.  Through the process of tidying it further we removed columns and rows which serve as no use to our analysis, this process and reasoning for doing so are below.
#
# Why we reduced the amount of tweets (from 1000 to 300),
# - Originally we wanted to analyze 1000 tweets per day from the date range of 2020-03-22 to 2021-01-22, however the size of the .json and dataframe that were generated from that loaded very slowly on our computers and was not practical.  In order to work more easily with the data, we reduced the number of tweets per day to 300 to speed up the process of loading/uploading the data.
#
# Why we filtered out other languages besides English and Spanish,
# - We are using a sentiment analysis API to analyze the sentiment of the tweets in our dataset, and the API only works on English and Spanish texts. On top of this, we are choosing to look mainly at political and current events in the United States, and English and Spanish are the two most common languages in the US by far.
#
# Why we dropped certain columns,
# - `__ID` and `_Str` attributes (e.g `quoted_status_id`, `quoted_status_id_str`, etc.) - unnecessary information
# - `In_reply_to` attributes (e.g `status_id`, `status_id_str`, etc.) - outside the scope of our analysis
# - Booleans - `truncated`, `possibly_sensitive` - all values False in these columns
# - `withheld_ attributes` → getting rid of the other two (`_scope`, and `_in_countries`) as it is unnecessary information, but planning to keep `withheld_copyright` since it contained a row with a “True” values so will filter out that row later on
# - User attributes (`source`, `contributors`) - unnecessary information
#
# Why we kept certain columns
# - `full_text` - gives us the actual tweet being made, which we are analyzing.
# - `lang`, `entities`, `extended_entities`, `withheld_copyright` - Gives us additional information about the tweet that is not shown in the text.  This can be emojis, links, etc. which help us to better understand the sentiment.
# - `is_quote_status`, `retweet_count`, `favorite_count`, `favoirited`, `retweeted` - Also give us some insight into how popular the tweet may have been, giving us some idea of how other people may be feeling about the same idea / topic.
# - `coordinates`, `geo`, `place`, `user` - contain user info (ex: location/coordinate info) that would be helpful to identify the region of the tweets.

# %%
#Reads in the json file into a dataframe
df = pd.read_json("tweets.json", lines=True, orient="records")
df.head()

# %%
def filterTweets(aDF):
    aDF = aDF.loc[(aDF['lang'] == 'en') | (aDF['lang'] == 'es') | (aDF['lang'] == 'und')]
    aDF = aDF[desiredColumns].reset_index(drop=True)
    return aDF

def dfToDictInChunks(df, chunkSize):
    dfList = [ df.loc[i : i + chunkSize - 1, :] for i in range(0, len(df), chunkSize)]
    dictList = []
    for slicedDF in dfList:  
        result = slicedDF.to_dict('records')
        dictList.append(result)
    return dictList

# Take an unformatted dictionary of tweets, and formats it to send to the api.
def formatDictList(unformattedDictList):
    formattedList = []
    for chunk in unformattedDictList:
        formattedDict = {}
        formattedDict['language'] = 'auto'
        formattedDict['data'] = chunk
        formattedList.append(formattedDict)
    
    return formattedList

# %%
# Filter unwanted columns and rows from df.
df = filterTweets(df)
# Make subset of DF to send to sentiment API
tweetsDF = df[ ['id', 'full_text'] ].copy()
tweetsDF.columns = ['id', 'text']

# format tweets and chunk into 10,000 tweet sublits to send to api
unformattedTweetsList = dfToDictInChunks(tweetsDF, 10000)
formattedTweetsList = formatDictList(unformattedTweetsList)

# %%
# Send tweets to sentiment api and add reponses to responseList
sentiment_url = 'http://www.sentiment140.com/api/bulkClassifyJson'

responseList = []
for tweetDict in formattedTweetsList:
    tempJSON = json.dumps(tweetDict)
    res = requests.post(sentiment_url, data=tempJSON)
    responseList.append(res)

# %% [markdown]
# Obtaining sentiment values for the text of each tweet in the dataset. Outline of Steps:
#
#    1. First we filter out the unwannted columns from our dataframe, using the function filterTweets, which drops  and tweet that is not of a language english, spanish, undefined (which is typically emojis or links).
#
#    2. Next we form a new DF "tweetsDF", which will be formatted specifically to send to the API Sentiment140.
#
#    3. Sentiment 140 only needs the ID and full text of each row.  Also it can only take 10,000 tweets at a time, so it needs to be chunked into 10,000 tweet blocks.
#
#    4. After sending the tweets to the API they needed to be grouped back into the main DF, which is done by merging the dfs on 'ID'.
#
#    5. Now all of the tweets have an associated sentiment or polarity, and we write that df to the disk as a .json.

# %%
# Clean up response into format that is easy to convert to JSON
text_polarity = {}
for response in responseList:
    for tweet in response.json()['data']:
        text_polarity[tweet['id']] = {
            'id' : tweet['id'],
            'text' : tweet['text'],
            'polarity' : tweet['polarity']
        }

# %%
# Write new data to its own json file
outfile = open("jsonWithSentiment.json", "w")
outfile.write(json.dumps(text_polarity, indent=4))
outfile.close()

# %%
# Convert json to DF
sentiment_df = pd.read_json(json.dumps(text_polarity), orient='index')
sentiment_df.head()
# Remove text row as it is redundent
reduced_df = sentiment_df[[ 'id', 'polarity' ]]
# Merge sentiment into main df, so that polarity is matched with its original tweet
df = pd.merge(df, reduced_df, on='id')
df.head()

# %%
df.to_json('tweets_with_sentiment.json', orient='records')

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# To describe the basic characteristics of this sample dataset, we calculated the statistics for tweet length, favorite counts and retweet counts, as well as the most common bigrams and trigrams.
# To test our hypothesis, we examined the sentiment of tweets across language, and across time, with one-way ANOVA, linear regression and bivariate correlation tests.

# %%
# Start by reading in json data
df = pd.read_json("tweets_with_sentiment.json", orient="records")
df.head()
# Out:
#            created_at                   id  \
# 0 2020-03-22 04:23:22  1241581211434311680
# 1 2020-03-22 04:45:18  1241586729435287554
# 2 2020-03-22 04:47:45  1241587346841038848
# 3 2020-03-22 05:02:55  1241591163422945280
# 4 2020-03-22 05:43:16  1241601318671843333
#
#                                            full_text display_text_range  \
# 0  The latest The Daniel Tay Daily! https://t.co/...            [0, 78]
# 1       #CoronavirusPandemic https://t.co/4etth0iWlD            [0, 20]
# 2             God bless you. https://t.co/HttD4WmQZA            [0, 14]
# 3  Burundi announced that it had suspended all fl...           [0, 150]
# 4  En diciembre pasado, intentó alertar a sus col...           [0, 252]
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'coronavirus', 'indices...
# 1  {'hashtags': [{'text': 'CoronavirusPandemic', ...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
ngram_df = df.copy()

# %%
#Cleans the text column of the data frame of just the hashtags, mentions and emojis.
df['clean_text'] = df['full_text'].apply(lambda x: p.clean(x))

# %%
df['tweet_length'] = df['clean_text'].str.len()
ax = sns.distplot(df['tweet_length'], kde=False, 
                  bins=50);
ax.axvline(df['tweet_length'].mean(), color='darkred', linestyle='--', label='mean');
ax.axvline(df['tweet_length'].median(), color='#2e2e2e', linestyle='--', label='median')
ax.legend();
sns.despine()
ax.set_title('Histogram of Length of Tweets')
ax.set_xlabel('Number of Characters per Tweet (full text)')
ax.set_ylabel('Number of tweets');

# %% [markdown]
# There are a large number of tweets that consist of just hashtags, mentions or emojis given the large amount of tweets with zero characters left after cleaning is performed. The mean of the length of tweets is around 104 characters and the most common values are around the 60's.

# %%
print( 'median: ', df['tweet_length'].median())
print( 'mean: ', df['tweet_length'].mean())
# Out:
# median:  86.0
# mean:  104.24822490423298

# %%
df['tweet_length'].value_counts().head(10)
# Out:
# 0     5229
# 67     463
# 72     449
# 74     445
# 71     429
# 77     423
# 60     420
# 63     416
# 65     412
# 59     411
# Name: tweet_length, dtype: int64

# %% [markdown]
# ##### Maximum
# Full_text_max variable to show the maximum length of a tweet. After using the ngrams cleaning function and using 'clean_text', tweeth length is 290. However, the maximum number of characters per tweet on Twitter is 280...
# Looking deeper into it, the index position at 39164 had a tweet that exceeded this length, however it was because this individual used the '&' in the tweet, and the text conversion becomes '&amp'. Since this person used it multiple times, the tweet length exceeded what would be the 280 limit on twitter, but is 295 in our data.

# %%
over = (df['tweet_length'].value_counts()> 280).sum()
print(over)
# Out:
# 57

# %%
full_text_max = df[df.clean_text.str.len() == max(df.clean_text.str.len())]
full_text_max
# Out:
#                created_at                   id  \
# 39164 2020-10-02 14:33:39  1312038039829573635
#
#                                                full_text display_text_range  \
# 39164  I had a mild case of COVID-19 &amp; it was AWF...           [0, 296]
#
#                                                 entities  \
# 39164  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                                     user   geo coordinates  \
# 39164  {'id': 34809502, 'id_str': '34809502', 'name':...  None        None
#
#       place  is_quote_status  ...  favorite_count  favorited  retweeted  lang  \
# 39164  None            False  ...               0      False      False    en
#
#       quoted_status extended_entities withheld_copyright  polarity  \
# 39164          None              None                NaN         0
#
#                                               clean_text tweet_length
# 39164  I had a mild case of COVID-19 &amp; it was AWF...          295
#
# ...

# %%
full_text_max['clean_text'][39164]
# Out:
# 'I had a mild case of COVID-19 &amp; it was AWFUL. I wouldnt wish this virus on anyone &amp; I hope the President, FLOTUS &amp; all recover quickly. However, I do hope this makes him take pause on the reality of how easily the virus spreads &amp; how he approaches talking about it moving forward'

# %% [markdown]
# ##### Minimum
# Full_text_min variable to show the minimum length of a tweet. Before using the ngrams cleaning function and using 'clean_text', the lowest length of a tweet was 3, however these were emoji's. After using the cleaning function and storing this data into 'clean_text', all tweets in full_text_min are empty. For example, the index position at 1 had a tweet that was 20 characters, however the only content was a hashtag and link. The cleaning function removes this, so using the clean_text column to analyze full_text_min outputs an empty string ''.

# %%
full_text_min = df[df.clean_text.str.len() == min(df.clean_text.str.len())]
full_text_min
# Out:
#                created_at                   id  \
# 1     2020-03-22 04:45:18  1241586729435287554
# 9     2020-03-22 09:18:10  1241655399264157696
# 13    2020-03-22 10:00:55  1241666157905686530
# 30    2020-03-22 13:50:36  1241723959575564288
# 40    2020-03-22 18:02:18  1241787301740589056
# ...                   ...                  ...
# 62274 2021-01-22 14:01:59  1352617509204221952
# 62341 2021-01-22 12:52:52  1352600114855108608
# 62364 2021-01-22 17:29:51  1352669823239659523
# 62366 2021-01-22 17:46:03  1352673898974867460
# 62386 2021-01-23 01:13:56  1352786610484600832
#
#                                                full_text display_text_range  \
# 1           #CoronavirusPandemic https://t.co/4etth0iWlD            [0, 20]
# 9                            🦠▶️ https://t.co/sQesoAQ6Xz             [0, 3]
# 13     @Scavino45 @realDonaldTrump @StateDept @SecPom...           [50, 73]
# 30                               https://t.co/EjxLZRhzxh            [0, 23]
# ...

# %%
full_text_min['full_text'][1]
# Out:
# '#CoronavirusPandemic https://t.co/4etth0iWlD'

# %%
full_text_min['clean_text'][1]
# Out:
# ''

# %% [markdown]
# ##### Favorite and Retweets

# %%
# Filtered out the time in the 'created_at' variable, leaving only the year-month-date that is relevant for our analysis
df['date']=df['created_at'].dt.date

# Extracted the 'followers_count' and 'statuses_count' values from the 'user' list of dictionaries, and put the list of values into two new columns
followers_count=[sub['followers_count'] for sub in df['user']]
status_count=[sub['statuses_count'] for sub in df['user']]
df['followers_count']=followers_count
df['status_count']=status_count
df.head()
# Out:
#            created_at                   id  \
# 0 2020-03-22 04:23:22  1241581211434311680
# 1 2020-03-22 04:45:18  1241586729435287554
# 2 2020-03-22 04:47:45  1241587346841038848
# 3 2020-03-22 05:02:55  1241591163422945280
# 4 2020-03-22 05:43:16  1241601318671843333
#
#                                            full_text display_text_range  \
# 0  The latest The Daniel Tay Daily! https://t.co/...            [0, 78]
# 1       #CoronavirusPandemic https://t.co/4etth0iWlD            [0, 20]
# 2             God bless you. https://t.co/HttD4WmQZA            [0, 14]
# 3  Burundi announced that it had suspended all fl...           [0, 150]
# 4  En diciembre pasado, intentó alertar a sus col...           [0, 252]
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'coronavirus', 'indices...
# 1  {'hashtags': [{'text': 'CoronavirusPandemic', ...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
retw_mean=pd.pivot_table(df, values='retweet_count', index=['date'])
fav_mean=pd.pivot_table(df, values='favorite_count', index=['date'])
retw_mean.head()
# Out:
#             retweet_count
# date
# 2020-03-22       0.757396
# 2020-03-23       1.980392
# 2020-03-24       5.606742
# 2020-03-25       1.079365
# 2020-03-26       2.294416

# %%
retw_meanplot=retw_mean.plot()
plt.xticks(rotation=45)
plt.ylabel("retweet_count")
plt.title("Average retweet count across time")
# Out:
# Text(0.5, 1.0, 'Average retweet count across time')

# %% [markdown]
# There are spikes in the retweet counts of COVID related tweets, this likely is due to the increase of cases reported as they coincide with the summer season and the holidays.

# %%
fav_meanplot=fav_mean.plot()
plt.xticks(rotation=45)
plt.ylabel("favorite_count")
plt.title("Average favorite count across time")
# Out:
# Text(0.5, 1.0, 'Average favorite count across time')

# %% [markdown]
# The favorite count has similar spikes as the retweet counts with a big spike around May and then periodic spikes around the summer and the holidays.

# %% [markdown]
# ##### Mean Followers & Statuses
# We calculated the mean followers and mean statuses for all the tweeters in our dataset.

# %%
mean_followers=sum(followers_count)/len(followers_count)
mean_followers
# Out:
# 76696.56788639387

# %%
mean_status=sum(status_count)/len(status_count)
mean_status
# Out:
# 74873.90120369925

# %% [markdown]
# ##### Exploration of Hashtags Usage

# %%
#flatten nested 'entities' col
entities = json_normalize(df['entities'])
hashtags = json_normalize(data = df['entities'], record_path='hashtags')
#top 20 common hashtags without standardizaion
text_hashtags = hashtags.text
df = df.assign(hashtags = text_hashtags)
df.hashtags.value_counts().head(20)
# Out:
# COVID19                7540
# coronavirus            2813
# covid19                1192
# Covid19                1134
# Coronavirus             982
# Covid_19                330
# COVIDー19                256
# COVID                   253
# pandemic                208
# Trump                   190
# CoronavirusPandemic     173
# CoronaVirus             163
# lockdown                156
# QuedateEnCasa           140
# covid                   137
# WearAMask               130
# vaccine                 128
# news                    111
# StayHome                105
# TrumpVirus              103
# Name: hashtags, dtype: int64

# %%
#standardize functions

def standardize_Covid (string):
    string = string.lower()
    string = string.strip()
    string =string.replace('covid_19', 'covid19')
    string =string.replace('covidー19', 'covid19')
    string =string.replace('covid__19', 'covid19')
    
    return string

def standardize_hashtags (string):
    string = string.lower()
    string = string.strip()
    string = string.replace('_',' ')
    string = string.replace('-',' ')
    string = string.replace('ー',' ')
    string = string.replace('vaccines','vaccine')
    
    if 'stayathome' in string:
        output = 'stayhome'
    elif 'quédateencasa' in string:
        output = 'quedateencasa'
    else:
        output = string
    
    output = string.strip()
    
    return output

# %%
updated_text_hashtags = text_hashtags.apply(standardize_hashtags)
updated_text_hashtags = text_hashtags.apply(standardize_Covid)
df = df.assign(updated_hashtags = updated_text_hashtags)
print('number of hashtags used: ', text_hashtags.nunique())
# top 20 common hashtags after standardizing
print('top 20 common used hashtags after standardizing')
df.updated_hashtags.value_counts().head(20)
# Out:
# number of hashtags used:  26428
# top 20 common used hashtags after standardizing
# covid19                10654
# coronavirus             4013
# covid                    483
# pandemic                 264
# trump                    249
# lockdown                 199
# coronaviruspandemic      192
# corona                   188
# news                     164
# quedateencasa            162
# stayhome                 161
# vaccine                  155
# wearamask                152
# staysafe                 140
# health                   139
# usa                      115
# trumpvirus               112
# china                    106
# pandemia                  98
# india                     97
# Name: updated_hashtags, dtype: int64

# %%
#count plot for standardized hashtags
fig = plt.gcf()
fig.set_size_inches( 22, 10)
# top 10 showed
sns.countplot(x = 'updated_hashtags', data = df, order=df.updated_hashtags.value_counts().iloc[:10].index).set(title='Count Plot for Top 10 Common Hastags after Cleaning')
# Out:
# [Text(0.5, 1.0, 'Count Plot for Top 10 Common Hastags after Cleaning')]

# %% [markdown]
# The barplot above shows the frequency of the top 10 used hashtags.
#
# As we can see,  the majority of the common hashtags are covid-related such as 'covid', 'pandemic', 'quedateencasa'(stayhome in spanish) and 'lockdown', while other event-related hashtags like 'trump' and 'news' are also commonly used. It is likely that there are some relationships between covid-related events, trump-related events and other events.

# %%
# set up for wordcloud

import wordcloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

def red_color_func(word, font_size, position,  orientation, font_path, random_state=None):
    h = int(190 * 45.0 / 255.0)
    s = int(60 * 255.0 / 255.0)
    l = int(100.0 * float(random_state.randint(60, 120)) / 255.0)

    return "hsl({}, {}%, {}%)".format(h, s, l)

def yellow_color_func(word, font_size, position,  orientation, font_path, random_state=None):
    h = int(280 * 45.0 / 255.0)
    s = int(60 * 255.0 / 255.0)
    l = int(100.0 * float(random_state.randint(60, 120))/ 255.0)

    return "hsl({}, {}%, {}%)".format(h, s, l)

# %%
# wordcloud for updated hashtags
wordcloud_hashtags_updated = WordCloud(scale=3,
                background_color ='white', 
                max_words=100, 
                stopwords=stopwords,
                min_font_size = 6, 
                color_func=red_color_func).generate_from_frequencies(updated_text_hashtags.value_counts())
plt.figure(figsize=(20,10))
plt.imshow(wordcloud_hashtags_updated, interpolation="bilinear")
plt.axis("off")
plt.title('Common Used Hashtags after Standardizing\n')
plt.show()

# %% [markdown]
# Besides COVID-related hashtags, there are also other common hashtags that are non-COVID related such as: Trump, wearamask, stayhome/quedateencasa, health, biden

# %%
# wordcloud for common used words in tweets
full_text = df['full_text'].apply(lambda x: p.clean(x))
full_text_split = ''.join(words for words in full_text)
stopwords = set(STOPWORDS)
stopwords_spanish = nltk.corpus.stopwords.words('spanish')
stopwords.update(stopwords_spanish)
stopwords.update(['-','https','t','co','via','y','de','en','el','e','U','su','s','lo','want','let','look','will','amp','o','es','re','la','m','al','del','por','but','una','se','un','don','si'])
wordcloud2 = WordCloud(scale=3,
                background_color ='white', max_words=150, stopwords=stopwords,
                min_font_size = 6, color_func= yellow_color_func).generate(str(full_text_split))

plt.figure(figsize=(20,10))
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.title('Common Used Words in Tweets\n')
plt.show()

# %% [markdown]
# Besides COVID-related words, there are also other common words in tweets such as: Death, people, time, Trump, vaccine, spread, help

# %%
nltk.download('stopwords')

def ngrams_cleaning(aDF):
    #Removes hashtags and emojis
    aDF['clean_text'] = aDF['full_text'].apply(lambda x: p.clean(x))

    #Removes punctuations and changes to lower case
    aDF['clean_text'] = aDF['clean_text'].apply(lambda x: re.sub(r'[^\w\s]', '', x))
    aDF['clean_text'] = aDF['clean_text'].apply(lambda x: x.lower())

    #Removes all the digits
    aDF['clean_text'] = aDF['clean_text'].apply(lambda x: re.sub('[0-9]', '', x))

    #Tokenizes the text to make it easier to analyze ngrams
    tokenizer = TweetTokenizer()
    aDF['clean_text'] = aDF['clean_text'].apply(lambda x: tokenizer.tokenize(x))

    #predefined stop words/common words
    stopwords_english = set(nltk.corpus.stopwords.words('english'))
    stopwords_spanish = set(nltk.corpus.stopwords.words('spanish'))
    #Removes all stopwords
    aDF['clean_text'] = aDF['clean_text'].apply(lambda x: [i for i in x if i not in stopwords_english])
    aDF['clean_text'] = aDF['clean_text'].apply(lambda x: [i for i in x if i not in stopwords_spanish])
    
    return aDF

def get_ngrams(aDF, n):
    return aDF['clean_text'].apply(lambda x: list(nltk.ngrams(x, n)))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/rsemaya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
clean_df = ngrams_cleaning(ngram_df)

# %%
bigrams = get_ngrams(clean_df, 2)
bigrams.head()
# Out:
# 0      [(latest, daniel), (daniel, tay), (tay, daily)]
# 1                                                   []
# 2                                       [(god, bless)]
# 3    [(burundi, announced), (announced, suspended),...
# 4    [(diciembre, pasado), (pasado, intent), (inten...
# Name: clean_text, dtype: object

# %%
bigrams = bigrams.explode().reset_index().drop("index", axis=1)
bigrams = bigrams.dropna(axis=0, how="any")
bigrams = bigrams.reset_index().drop("index", axis=1)

# %%
bigrams.head()
# Out:
#              clean_text
# 0      (latest, daniel)
# 1         (daniel, tay)
# 2          (tay, daily)
# 3          (god, bless)
# 4  (burundi, announced)

# %%
bigrams['clean_text'].value_counts()
# Out:
# (covid, cases)            757
# (covid, vaccine)          697
# (covid, pandemic)         640
# (new, cases)              484
# (coronavirus, cases)      441
#                          ...
# (chileno, vacunado)         1
# (burgess, coronavirus)      1
# (coronavirus, bio)          1
# (brind, opinin)             1
# (personas, mesasde)         1
# Name: clean_text, Length: 431527, dtype: int64

# %% [markdown]
# #### N-gram Visualizations
# To better see the frequency of bigram and trigram pairs, we made horizontal bar graphs to visualize the frequency.

# %% [markdown]
# ###### Bigrams

# %%
bigrams_series = (pd.Series(bigrams['clean_text'].value_counts().head(12)))[:12]

# %%
# Make the graph for most frequently occuring bigrams 
bigrams_series.sort_values().plot.barh(color='blue', width=.9, figsize=(12, 8))
plt.title('12 Most Frequently Occuring Bigrams')
plt.ylabel('Bigram')
plt.xlabel('# of Occurances')
# Out:
# Text(0.5, 0, '# of Occurances')

# %% [markdown]
# Many of the bigrams relate to new coronavirus cases which demonstrates the amount of people that worried about potentially contracting COVID-19 and the rising cases within the United States as well as the world.
#
# Similar to the bigrams, most of the trigrams relate to new coronavirus cases. Interestingly, the New York Times makes an appearance a significant amount of times as well as the trigram (f, f, f). This is because of one spam tweet (shown below) which has multiple f's separated by a space which the ngram takes into account.

# %% [markdown]
# ##### Trigrams

# %%
trigrams = get_ngrams(clean_df, 3)
trigrams.head()
# Out:
# 0        [(latest, daniel, tay), (daniel, tay, daily)]
# 1                                                   []
# 2                                                   []
# 3    [(burundi, announced, suspended), (announced, ...
# 4    [(diciembre, pasado, intent), (pasado, intent,...
# Name: clean_text, dtype: object

# %%
trigrams = trigrams.explode().reset_index().drop("index", axis=1)
trigrams = trigrams.dropna(axis=0, how="any")
trigrams = trigrams.reset_index().drop("index", axis=1)

# %%
trigrams['clean_text'].value_counts()
# Out:
# (new, covid, cases)             178
# (f, f, f)                       110
# (new, coronavirus, cases)        98
# (tested, positive, covid)        90
# (test, positive, covid)          67
#                                ...
# (lleno, coronavirus, vacuna)      1
# (factory, rss, make)              1
# (must, stored, degrees)           1
# (passionate, beating, covid)      1
# (us, set, recommend)              1
# Name: clean_text, Length: 497781, dtype: int64

# %%
trigrams_series = (pd.Series(trigrams['clean_text'].value_counts().head(12)))[:12]

# %%
# Make the graph for most frequently occuring trigrams 
trigrams_series.sort_values().plot.barh(color='blue', width=.9, figsize=(12, 8))
plt.title('12 Most Frequently Occuring Trigrams')
plt.ylabel('Trigram')
plt.xlabel('# of Occurances')
# Out:
# Text(0.5, 0, '# of Occurances')

# %%
ngram_df.loc[7258]['full_text']
# Out:
# 'How in the effin’ f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f f did we ever f’in get f’in here?! Ffs. https://t.co/bsbkd1W7v3'

# %% [markdown]
# ##### Sentiment of Tweets
# Examining the sentiment of tweets in the dataset. The sentiment is evaluated on a scale of polarity, where 0 = negative, 2 = neutral, and 4 = positive. First we should look at what the average sentiment of the tweets.

# %%
sent_avg = pd.pivot_table(df, values='polarity', index=['date'], aggfunc=np.average)
sns.countplot(data=df, x='polarity')

# %%
df['polarity'].mean()
# Out:
# 2.0372489621900596

# %% [markdown]
# As we can see the average tweet has neutral polarity. And if we look at average polarity per day it is very common for days to have an average of around 2.05 sentiment. On the high end days have an average of around 2.18 and on the low end 1.9.
#
# Now lets look at the average graphed out per day to see if it fluctuates a lot depending on the day/month.

# %%
plt.figure(figsize=(16,6))
ax = sns.lineplot(data=sent_avg, legend=False)
plt.xticks(rotation=30)
ax.set_xlabel('Date')
ax.set_ylabel('Avg. Polarity')
ax.set_title("Average Polarity by Day")
# Out:
# Text(0.5, 1.0, 'Average Polarity by Day')

# %% [markdown]
# ##### Sentiment Across Time
# To better see the sentiment trend over time, we ran a correlation test and a linear regression to see if sentiment is negatively correlated with time and that if time is a significant predictor for sentiment in tweets.

# %%
#assign values to the date to better see the relationship trend between polarity and time 
df['date-int'] = pd.to_datetime(df['date']).dt.strftime('%Y%m%d').astype(int)
date_dict = df['date-int'].value_counts()
date_list = list(date_dict.keys())
date_list.sort()
date_int_map = {}

cur_int = 1
for date in date_list:
    if date not in date_int_map:
        date_int_map[date] = cur_int
        cur_int += 1

df['date_val'] = df['date-int'].apply(lambda x : date_int_map[x])
df['date_val']=df['date_val'].astype(np.int)
df.head()
# Out:
#            created_at                   id  \
# 0 2020-03-22 04:23:22  1241581211434311680
# 1 2020-03-22 04:45:18  1241586729435287554
# 2 2020-03-22 04:47:45  1241587346841038848
# 3 2020-03-22 05:02:55  1241591163422945280
# 4 2020-03-22 05:43:16  1241601318671843333
#
#                                            full_text display_text_range  \
# 0  The latest The Daniel Tay Daily! https://t.co/...            [0, 78]
# 1       #CoronavirusPandemic https://t.co/4etth0iWlD            [0, 20]
# 2             God bless you. https://t.co/HttD4WmQZA            [0, 14]
# 3  Burundi announced that it had suspended all fl...           [0, 150]
# 4  En diciembre pasado, intentó alertar a sus col...           [0, 252]
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'coronavirus', 'indices...
# 1  {'hashtags': [{'text': 'CoronavirusPandemic', ...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
#Explore the relationship between time and sentiment in tweets through correlation coefficients
np.corrcoef(df['polarity'], df['date_val'])
# Out:
# array([[ 1.        , -0.00594823],
#        [-0.00594823,  1.        ]])

# %%
#Test whether time is a significant predictor for tweets sentiment
outcome, predictors = patsy.dmatrices('polarity ~ date_val ', df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               polarity   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     2.207
# Date:                Tue, 16 Mar 2021   Prob (F-statistic):              0.137
# Time:                        15:50:50   Log-Likelihood:                -75040.
# No. Observations:               62391   AIC:                         1.501e+05
# Df Residuals:                   62389   BIC:                         1.501e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0457      0.007    312.092      0.000       2.033       2.059
# ...

# %% [markdown]
# We found that sentiment is slightly negatively correlated with time, such that as time goes by, the sentiment in tweets became more negative, although not significant (r = -0.006). Moreover, in the linear regression model where time is the sole predictor of tweets sentiment, we found that time is not a significant predictor for sentiment in tweets (F(1,62389) = 2.21, p = 0.14).

# %% [markdown]
# ##### Sentiment by Language
#
# To better understand if language is a predictor for sentiment in the tweets, we ran an one-way ANOVA with language as the independent variable and sentiment polarity as the dependent variable; we also ran a post-hoc Tukey HSD test (to control for family wise error rate) to test pairwise comparisons.

# %%
sent_lang_avg = pd.pivot_table(df, values='polarity', index=['lang'], aggfunc=np.average)
sent_lang_avg
# Out:
#       polarity
# lang
# en    2.002654
# es    2.163712
# und   2.025616

# %%
sns.barplot(data=df,x='lang',y='polarity')
plt.title('Average Sentiment by Language')
plt.ylabel('Sentiment')
plt.xlabel('Language')
# Out:
# Text(0.5, 0, 'Language')

# %% [markdown]
# To briefly look at how sentiment across language differ, we made a bar graph to show the mean polarity of each language. We can see that Spanish tweets seems to have a more positive polarity than the other two languages.

# %%
comb_polarity = df[(df['lang'] == 'es') | (df['lang'] == 'en')]
comb_sent_avg = pd.pivot_table(comb_polarity, values=['polarity'], index=['date', 'lang'], aggfunc=np.average)
comb_sent_avg
# Out:
#                  polarity
# date       lang
# 2020-03-22 en    1.932203
#            es    2.171429
# 2020-03-23 en    2.136364
#            es    2.093023
# 2020-03-24 en    2.000000
# ...                   ...
# 2021-01-21 es    2.210526
# 2021-01-22 en    1.960000
#            es    2.105263
# 2021-01-23 en    1.894737
#            es    1.777778
#
# [616 rows x 1 columns]

# %%
sns.histplot(data=comb_sent_avg, x='polarity', hue='lang', multiple='layer')
plt.xticks(rotation=45)
# Out:
# (array([1.6, 1.8, 2. , 2.2, 2.4, 2.6]),
#  <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# Plotting the average sentiment of tweets separated between English and Spanish, we get a clear picture that Spanish tweet tended to be more positive than English. This gives us a good indication that language might be a significant predictor for the sentiment of tweets. Excluded 'und' (undefined) column because most of the text was emojis or links, and the polarity was neutral.

# %%
# Test whether language is a significant predictor for sentiment in a simple regression test
outcome, predictors = patsy.dmatrices('polarity ~ lang ', df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               polarity   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     196.5
# Date:                Tue, 16 Mar 2021   Prob (F-statistic):           8.89e-86
# Time:                        15:50:52   Log-Likelihood:                -74845.
# No. Observations:               62391   AIC:                         1.497e+05
# Df Residuals:                   62388   BIC:                         1.497e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       2.0027      0.004    521.308      0.000       1.995       2.010
# ...

# %%
# get an ANOVA table and F statistics
import statsmodels.api as sm
from statsmodels.formula.api import ols
model = ols('polarity ~ lang', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df           F        PR(>F)
# lang        253.397991      2.0  196.453176  8.892137e-86
# Residual  40236.035421  62388.0         NaN           NaN

# %%
# perform multiple pairwise comparison (Tukey HSD)
from statsmodels.stats.multicomp import pairwise_tukeyhsd
m_comp = pairwise_tukeyhsd(endog=df['polarity'], groups=df['lang'], alpha=0.05)
print(m_comp)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     en     es   0.1611  0.001   0.142  0.1801   True
#     en    und    0.023 0.0894 -0.0026  0.0486  False
#     es    und  -0.1381  0.001 -0.1674 -0.1088   True
# ----------------------------------------------------

# %% [markdown]
# We can see that language is a significant predictor for tweet sentiments (F(2,62388) = 196.45, p<0.001). Specifically, Spanish tweets (M = 2.16) are significantly more postive than English tweets (M = 2.00; p = 0.001).

# %%
lowest_sent_all = sent_avg.sort_values(by=['polarity']).head(5)
lowest_sent_all
# Out:
#             polarity
# date
# 2021-01-23  1.870968
# 2020-11-15  1.872146
# 2020-07-07  1.883408
# 2020-10-09  1.888889
# 2020-12-29  1.896907

# %% [markdown]
# ##### Some current events that were tied to the top 5 lowests days were:
#
# 2021-01-23:
#
# [CDC reports record number of daily Covid-19 vaccinations as states struggle with supply](https://www.cnn.com/2021/01/22/health/us-coronavirus-friday/index.html)
#
# [Michigan county commissioner pulls gun out during virtual meeting when resident asked board to denounce Proud Boys](https://www.cnn.com/2021/01/22/us/michigan-county-commissioner-gun-proud-boys/index.html)
#
# [Two educators in the same Georgia school district died within hours from Covid-19](https://www.cnn.com/2021/01/22/us/georgia-educators-die-within-hours-from-covid-19-trnd/index.html)
#
# 2020-11-15:
#
# [John Hopkins Uni announced US supassed 11 million covid cases, 2020-11-13 Shooting in N. Carolina.](https://www.infoplease.com/november-2020-current-events-us-news)
#
# [Indoor Venues Responsible for Much of COVID-19’s Spread](https://www.nytimes.com/2020/11/10/health/covid-indoor-venues-infections.html)
#
# 2020-07-07:
#
# [ICE announced that it will pull visas from international students who are attending universities that have switched to online.](https://www.theverge.com/2020/7/6/21315168/ice-immigration-international-students-universities-deportation)
#
# [US Surpasses 3 Million Infections, Begins WHO Withdrawal.](https://www.npr.org/sections/goatsandsoda/2020/07/07/888186158/trump-sets-date-to-end-who-membership-over-its-handling-of-virus)
#
# 2020-10-09:
#
# [The Trump Administration announced plans to place some restrictions on the H-1B Visa.](https://www.forbes.com/sites/stuartanderson/2020/10/07/trump-administration-issues-two-new-rules-to-restrict-h-1b-visas/?sh=63644ad35120)
#
# [White House COVID-19 Outbreak Grows to 34.](https://abcnews.go.com/Politics/34-people-connected-white-house-previously-infected-coronavirus/story?id=73487381)
#
# 2020-12-29:
#
# [Zhang Zhan, the Chinese journalist who recorded the outbreak of COVID in Wuhan, was sentenced to four years in prison.](https://www.washingtonpost.com/world/asia_pacific/china-wuhan-journalist-trial-coronavirus/2020/12/28/01fac40c-48b7-11eb-97b6-4eb9f72ff46b_story.html)
#
# [Spain announced that while the vaccine is not mandatory, the country will keep a registry of those who refuse
#     to take it.](https://www.bbc.com/news/world-europe-55471282)
#
# [The US reported its first case of the new strain of COVID in Colorado.](https://www.cnbc.com/2020/12/28/us-confirms-first-case-of-the-new-covid-strain-discovered-in-uk-.html)

# %%
highest_sent_all = sent_avg.sort_values(by=['polarity'], ascending=False).head(5)
highest_sent_all
# Out:
#             polarity
# date
# 2021-01-04  2.209424
# 2020-05-29  2.180000
# 2020-05-01  2.177778
# 2020-04-07  2.173913
# 2020-10-07  2.169643

# %% [markdown]
# ##### Some current events that were tied to the top 5 highest days were:
#
# We attempted to look for positive articles relating to covid that might relate to possitive days, but the selection was fairly sparse.
#
# 2021-01-04:
#
# [Mexico approves AstraZeneca vaccine for emergency use](https://www.cnn.com/world/live-news/coronavirus-pandemic-vaccine-updates-01-04-21/index.html)
#
# [Biden adviser says new administration will support states in Covid-19 vaccine roll out: "It's not a hand-off"](https://www.cnn.com/world/live-news/coronavirus-pandemic-vaccine-updates-01-04-21/index.html)
#
#
# 2020-05-29:
#
# [Trump again claims coronavirus is "going away"](https://www.cnn.com/world/live-news/coronavirus-pandemic-05-29-20-intl/index.html)
#
# [Florida approves Walt Disney World and Sea World reopening plans](https://www.cnn.com/world/live-news/coronavirus-pandemic-05-29-20-intl/index.html)
#
# 2020-05-01:
#
# ["We have begun to get on top of this virus," UK health official](https://www.cnn.com/world/live-news/coronavirus-pandemic-05-01-20-intl/index.html)
#
# [UK accomplishes its target of 100,000 coronavirus tests a day](https://www.cnn.com/world/live-news/coronavirus-pandemic-05-01-20-intl/index.html)
#
# 2020-04-07:
#
# [Trump on January memos about coronavirus: "I didn't see them, I didn't look for them either"](https://www.cnn.com/world/live-news/coronavirus-pandemic-04-07-20/index.html)
#
#
# 2020-10-07:
#
# [Kamala Harris rips Trump administration's response to coronavirus pandemic in only debate with Mike Pence](https://www.cnn.com/world/live-news/coronavirus-pandemic-10-07-20-intl/index.html)

# %% [markdown]
# ##### Vaccine Announcements

# %%
#1st covid vaccine(pfizer) approved by FDA: Dec 11 2020
#source: https://www.fda.gov/news-events/press-announcements/fda-takes-key-action-fight-against-covid-19-issuing-emergency-use-authorization-first-covid-19
df_sentiment = df
df_sentiment.set_index(['created_at'], inplace = True)
df_sentiment.head()
Dec_11th = df_sentiment['2020-12-11']

# %% [markdown]
# Taking a look at basic statistics for the polarity of Dec 11th: we see that the mean is slightly negative

# %%
Dec_11th['polarity'].describe()
# Out:
# count    190.000000
# mean       1.978947
# std        0.741498
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        4.000000
# Name: polarity, dtype: float64

# %%
#common used words in tweets on Dec 11th
full_text_dec_11 = Dec_11th['full_text'].apply(lambda x: p.clean(x))
full_text_dec_11_split = ''.join(words for words in full_text_dec_11)
stopwords = set(STOPWORDS)
stopwords_spanish = nltk.corpus.stopwords.words('spanish')
stopwords.update(stopwords_spanish)
stopwords.update(['-','https','t','co','via','y','de','en','el','e','U','su','s','lo','want','let','look','will','amp','o','es','re','la','m','al','del','por','but','una','se','un','don','si'])
wordcloud2 = WordCloud(scale=3,
                background_color ='white', max_words=100, stopwords=stopwords,
                min_font_size = 6, color_func= yellow_color_func).generate(str(full_text_dec_11_split))

plt.figure(figsize=(20,10))
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.title('Common Used Words in Tweets on Dec 11th\n')
plt.show()

# %%
sns.countplot(data = Dec_11th,x= 'polarity').set(title='Polarity of Tweets on Dec 11th')
# Out:
# [Text(0.5, 1.0, 'Polarity of Tweets on Dec 11th')]

# %%
#First shot taken in the US: Dec 14th 2020
#source: https://www.washingtonpost.com/nation/2020/12/14/first-covid-vaccines-new-york/
Dec_14th = df_sentiment['2020-12-14']
Dec_14th_sentiment = pd.pivot_table(Dec_14th, values='polarity', index=['created_at'])

# %%
Dec_14th['polarity'].describe()
# Out:
# count    236.000000
# mean       1.991525
# std        0.771798
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        4.000000
# Name: polarity, dtype: float64

# %%
#common used words on Dec 14th
full_text_dec_14 = Dec_14th['full_text'].apply(lambda x: p.clean(x))
full_text_dec_14_split = ''.join(words for words in full_text_dec_14)
stopwords = set(STOPWORDS)
stopwords_spanish = nltk.corpus.stopwords.words('spanish')
stopwords.update(stopwords_spanish)
stopwords.update(['-','https','t','co','via','y','de','en','el','e','U','su','s','lo','want','let','look','will','amp','o','es','re','la','m','al','del','por','but','una','se','un','don','si'])
wordcloud2 = WordCloud(scale=3,
                background_color ='white', max_words=100, stopwords=stopwords,
                min_font_size = 6, color_func= yellow_color_func).generate(str(full_text_dec_14_split))

plt.figure(figsize=(20,10))
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.title('Common Used Words in Tweets on Dec 14th\n')
plt.show()

# %% [markdown]
# Compared to Dec 11th, this day there were more mentions of 'first' because the first vaccine was administered to a person.

# %%
sns.countplot(data = Dec_14th,x= 'polarity').set(title='Polarity of Tweets on Dec 14th')
# Out:
# [Text(0.5, 1.0, 'Polarity of Tweets on Dec 14th')]

# %%
#Dr Fauci’s took his first covid vax(Moderna): Dec 22nd 2020
#source: https://www.vox.com/2020/12/22/22195300/anthony-fauci-covid-19-vaccine-tv-moderna
Dec_22nd = df_sentiment['2020-12-22']

# %%
#common used words on Dec 22nd
full_text_dec_22 = Dec_22nd['full_text'].apply(lambda x: p.clean(x))
full_text_dec_22_split = ''.join(words for words in full_text_dec_22)
stopwords = set(STOPWORDS)
stopwords_spanish = nltk.corpus.stopwords.words('spanish')
stopwords.update(stopwords_spanish)
stopwords.update(['-','https','t','co','via','y','de','en','el','e','U','su','s','lo','want','let','look','will','amp','o','es','re','la','m','al','del','por','but','una','se','un','don','si'])
wordcloud2 = WordCloud(scale=3,
                background_color ='white', max_words=100, stopwords=stopwords,
                min_font_size = 6, color_func= yellow_color_func).generate(str(full_text_dec_22_split))

plt.figure(figsize=(20,10))
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.title('Common Used Words in Tweets on Dec 22nd\n')
plt.show()

# %% [markdown]
# Compared to the previous word clouds about, we can see that the word ‘vaccine’ are more commonly used, also the frequency of usage of the word ‘dr’ has increased because Dr. Fauci took his first covid vaccine on Dec 22nd.

# %%
Dec_22nd['polarity'].describe()
# Out:
# count    201.000000
# mean       2.000000
# std        0.748331
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        4.000000
# Name: polarity, dtype: float64

# %%
sns.countplot(data = Dec_22nd,x= 'polarity').set(title='Polarity of Tweets on Dec 22nd')
# Out:
# [Text(0.5, 1.0, 'Polarity of Tweets on Dec 22nd')]

# %% [markdown]
# ##### Removing neutral tweets for Dec 11th, 14th, 22nd
# This helps us see the difference between positive and negative polarity better

# %%
Dec_11th_pos_neg = Dec_11th[Dec_11th['polarity'].isin([0,4])]
sns.countplot(data = Dec_11th_pos_neg,x= 'polarity').set(title='Polarity of Tweets on Dec 11th After Removing the Neutral Tweets')
# Out:
# [Text(0.5, 1.0, 'Polarity of Tweets on Dec 11th After Removing the Neutral Tweets')]

# %% [markdown]
# After removing neutral tweets, we can see that there were more negative tweets on Dec 11th.

# %%
Dec_14th_pos_neg = Dec_14th[Dec_14th['polarity'].isin([0,4])]

# %%
sns.countplot(data = Dec_14th_pos_neg,x= 'polarity').set(title='Polarity of Tweets on Dec 14th After Removing the Neutral Tweets')
# Out:
# [Text(0.5, 1.0, 'Polarity of Tweets on Dec 14th After Removing the Neutral Tweets')]

# %% [markdown]
# After removing neutral tweets, we can see that there were slightly more negative tweets on Dec 14th.

# %%
Dec_22nd_pos_neg = Dec_22nd[Dec_22nd['polarity'].isin([0,4])]
sns.countplot(data = Dec_22nd_pos_neg,x= 'polarity').set(title='Polarity of Tweets on Dec 22nd After Removing the Neutral Tweets')
# Out:
# [Text(0.5, 1.0, 'Polarity of Tweets on Dec 22nd After Removing the Neutral Tweets')]

# %% [markdown]
# Compared to the previous two graphs, we can see that the number of negative and positive tweets on Dec 22nd was similar.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# The sentiment of a tweet is subjective; the algorithm which determines the sentiment may not always be accurate. The group of individuals who use twitter may fall into specific categories, i.e. age groups, political affiliations, etc., and this may bias the events which cause the sentiment of tweets to vary.  We will try to mitigate this bias by using random subsets of tweets, and therefore attempting to achieve the most diverse set of opinions as possible, however this is limited to the demographics of the twitter user base.
#
# The data gathered for our project is within the public domain, and is available to anyone through twitter.  Our analysis will not include any information about users more than is available through their twitter profile.  We are obtaining the data through both the twitter api and apis managed by other groups.  Because of this we are not obtaining consent from any individuals to use their twitter information, however we will be obtaining consent from the owners of the apis we are using in order to gain access to their datasets.
#
# The data we are interested in, specifically the types of tweets that made it into our dataset, is outlined in the data cleaning section. We specifically altered the dataset into Tidy Data Format (json), reduced the number of tweets per day, filtered out language, dropped and kept certain columns from the twitter data directory. Ultimately, modifying our dataset to only include certain aspects from the initial directory will affect our analysis in that it narrows down what we are specifically looking to analyze, which is the sentiment of tweets relating to the COVID-19 pandemic. However, the process of filtering out the data to include certain types of tweets may overlook some basic information, leading to bias in our final analysis.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# We came into this analysis asking the following question: How has the sentiment of tweets been impacted and changed over the course of the COVID-19 pandemic when factoring in highly significant events that took place, specifically the emergence and approval of the COVID-19 vaccine, and language differences?
#
# Throughout our analysis, we observed that the results did not support our hypothesis which stated that the sentiment of tweets became more negative as a function of time. Through a bivariate correlation test, we found that sentiment of tweets is negatively correlated with time. However, in a subsequent linear regression test in which time was the independent variable and tweet sentiment was the dependent variable, we found that time was not a significant predictor for sentiment of tweets.
#
# Furthermore, the results did not support our hypothesis that on days where there were significant events, such as the vaccine announcements, the sentiment of tweets would show more significant positivity. On days with important vaccine announcements, the sentiment for these days were still similar to the overall sentiment of our dataset which is not what we expected. However, on these days there were clear increases in usage of the words “vaccines”, “first”, and “Dr.” in tweets, demonstrating that users were interested in these events. Interestingly, we did find a significant difference in the sentiment of English and Spanish tweets which was unexpected. Moreover, post-hoc pairwise comparisons tests suggest that Spanish tweets show significantly more positive sentiment than English tweets. Future research should look deeper into why this might have occurred.
#
# Although the API we used to analyze the sentiment of our tweet dataset is typically considered one of the best APIs for analyzing tweets, it did seem to have some limitations in regards to our analysis.  First of all, because tweets are not a typical form of human language the API relies heavily on categorization of tweets to aid in analyzing their sentiment.  Additionally, our tweets were grouped together through the category of “Covid”, however this did not aid the API very much in terms of its analysis with categorized tweets and non-categorized tweets receiving the same evaluations.  We believed that because of this many tweets were labeled as neutral when they maybe should not have been, and many other tweets seems to have been miscategorized.

# %% [markdown]
# # Team Contributions

# %% [markdown]
# - Rachel Semaya: Introduction (Background, Research Q, overview, etc.) worked on data analysis (Length of tweets, maximum, minimum), worked on ethics, compiled everything for final project, final video, discussion/conclusion
# - Matthew Sao: Created data pipeline to collect tweet IDs from Panacea Lab, worked on data section of notebook and the bigram and trigram analysis, discussion/conclusion, final video
# - Brian Sanders: Obtained sentiment for tweets, made changes to df format to allow for further investigation, worked on analyzing/visualizing sentiment for tweets, worked on ethic section, discussion/conclusion, final video
# - Shuyuan Shi: data visualizations for n-grams & retweets/favorites, statistical analysis and interpretation for sentiment across time & language, discussion/conclusion, final video
# - Ming Qiu: analyzed the common used hashtags and the common used words in the text of tweets, research on major vaccine announcement as well as the visualization of the sentiment of the tweets on these days, final video
