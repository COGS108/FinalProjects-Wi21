# %% [markdown]
# # **COGS 108 - Partner Selection in Dating**

# %% [markdown]
# ## **Overview**
# In this study, we analyzed various potential factors that affected an individual’s desirability as a potential partner. The dataset we used was from a speed dating study that observed individual decisions which played a role in selecting a possible partner. First, we cleaned this dataset so it was easier to understand and analyze. Then, we drew graphs to better understand our data and the relationships it contained. Finally, we used our analysis to suggest an answer to our initial question(s).

# %% [markdown]
# ## **Names**
# *   Lisa Dang
# *   Danny Ha
# *   Justin Le
# *   Destynee Tau
# *   Pauline Thach

# %% [markdown]
# ## **Research Question**
# How does a person’s racial background and religion affect their desirability as a potential partner? Do factors such as similar characteristics (i.e. personality traits, interests) make a more positive first impression, therefore increasing the likelihood of attraction? Furthermore, are females or males more desirable, in essence, who's more likely to secure a date?

# %% [markdown]
# ## **Background & Prior Research**
#
# As college students, most of us are not unfamiliar with the idea of dating whether we’ve experienced it first-hand or seen it with our friends and family. However, dating, itself, is not a universally shared experience as different people have different attributes for what they look for in a significant other. Some attributes include attractiveness, sincerity, intelligence, fun, ambition, and shared interests.
#
# In Western culture, dating is usually seen as a period where “people engage in informal and often polygamous relationships” [1] where people try to find someone that they deem fit and compatible enough to settle down with. Nevertheless, every dating experience is different since there are many variables that come into play when it comes to dating. So, we wanted to look more into how personal qualities affect one’s desirability as a potential partner and how attraction comes into play when similar interests or traits are introduced to one another.
#
# Most of the studies conducted to test attraction are well-controlled experiments which raises the concern for a lack of ecological validity [3, 4]. However, Ray Fisman and Sheena Iyengar’s speed dating experiment combats that concern. Their speed-dating scenario provides experimental control yet also gives data on decisions made in a setting that mimics real world scenarios [1]. Therefore, we decided to use data from their experiment as we deemed it was the best fit experiment for our research question. From other previous speed-dating studies, there’s been a consistent finding in how the strongest predictor of attraction was physical attractiveness which is seen across both sexes [3].
#
# In our chosen study, researchers used fliers and emails to recruit students for the experiment. Trials took place during speed dating events held at popular restaurants near campus and to keep the environmental settings constant, trials at each location kept the same table arrangements, music, and lighting to reduce external factors from influencing outcomes.
#
# During the experiment, participants would rank certain attributes of their dates on paper and determine if they would be a match. Included in these attributes were attractiveness, sincerity, intelligence, humor, ambition, and shared interests. Moreover, specific activities were laid out for participants to rank for interest such as sports, hiking, movies, and music. They also marked how important their partners’ race and religion were to them when deciding on being a match. All these factors helped researchers to uncover how individuals gauge if a person could be a suitable mate. They found that people do in fact have strong racial preferences when it comes to finding a partner even more so than having shared interests.
#
# In previous studies regarding dating preferences, physical attractiveness played a pivotal role in matching with a partner. Both men and women were found to value their partners’ appearance but there was no statistical significance in correlations for similarity of personalities and character traits [3]. This tells us that in dating, appearance is more important in a first impression than similarity. However, this does not mean that similarity is eliminated for initial romantic liking. According to one study, people do respond to perceived similarity in one another for attraction, but not to actual similarity [4]. For perceived notions of similarity, dates were more successful for individuals who expressed similar interests during the date itself. But when individuals completed personality trait assessments prior to the dates, the actual similarities between partners were lacking and did not lead to initial attraction. Based on this finding, similar interests and traits are not as important in finding a potential partner but do play a small part in initial attraction in addition to appearance.
#
# These research papers have led us to explore the idea of romantic attraction and how so many different variables come into play. Attraction is multi-dimensional and we want to study short-term and long-term to see if there’s a difference in attraction between people who are seeking ideal partners and people who aren’t necessarily looking to settle down yet. We believe that by exploring our research topic, we will have a better understanding of why certain dating preferences may exist.
#
# ---
#
# 1. Fisman, Iyengar, Kamenica & Simonson (2006) - Gender Differences in Mate Selection
# https://pdfs.semanticscholar.org/c51b/e9f818f0ecff3e705f0f7d35ccd748bae3ae.pdf?_ga=2.14097586.401217499.1611810866-1263278245.1611810866
#
# 2. Fisman, Iyengar, Kamenica & Simonson (2006) - Racial Preferences in Dating
# https://www0.gsb.columbia.edu/mygsb/faculty/research/pubfiles/866/racialPreferences.pdf
#
# 3. Luo & Zhang (2009) - What Leads to Romantic Attraction: Similarity, Reciprocity, Security, or Beauty?
# https://www.researchgate.net/publication/26322693_What_Leads_to_Romantic_Attraction_Similarity_Reciprocity_Security_or_Beauty_Evidence_From_a_Speed-Dating_Study
#
# 4. Tidwell, Eastwick & Finkel (2012) - Perceived Similarity Predicts Initial Attraction in a Romantic Context
# https://faculty.wcas.northwestern.edu/eli-finkel/documents/InPress_TidwellEastwickFinkel_PersonalRelationships_000.pdf
#
# ---

# %% [markdown]
# ## **Hypothesis**
# We hypothesize that when it comes to meeting potential partners, desirability from the first impression stems from a person’s physical attractiveness and similar interests. From our prior research, we also believe that women are more likely to secure a date. We believe that physical attractiveness is the first thing partners look at because one of the principles of social psychology regarding initial attraction states that finding someone attractive is one of the first stages of wanting to develop a romantic relationship.

# %% [markdown]
# ## **Dataset**
#
# Our ideal dataset would be to gather information from dating experiments that had partipants meet with one another and collect their responses for preference in racial backgrounds, interests, and religion to see if these factored in to an increased likelihood of matching together. We would then analyze the results of matched pairings if they displayed correlation of preferences which would then aid in our conclusion if desirability does increase in response to similarities and appearance.
#
# ---
#
# We will be analyzing data obtained from a speed dating study conducted by Columbia Business School professors, Ray Fisman and Sheena Iyengar, who wanted to observe the individual decisions that went into selecting a possible mate:
#
# **Gender Differences in Mate Selection: Evidence From a Speed Dating Experiment**
#
# **Source:** http://www.stat.columbia.edu/~gelman/arm/examples/speed.dating/
#
# **Number of observations:** ~ 8,000
#
# **Variables:** Attractiveness, sincerity, fun, ambition, intelligence, shared
# interests, racial/ethnic background
#
# **Method:** Data was collected from students at Columbia University recruited by e-mails and fliers. Trials took place during speed dating events held at popular restaurants near campus. Participants would rank certain attributes of their dates on paper and determine if they would be a match.
#
#
# This dataset has over 8,000 observations gathered over a course of two years (2002-2004). The study provided us with approximately 200 data points for each observation in relation to each participant’s racial background, desired traits in partners, and shared interests. Using this information, our group will be able to answer our research questions on whether certain qualities of a person and similarities increase the likelihood of finding a match. For this particular dataset, we will be reducing the amount of data points set out for us so that we can simplify the data and focus on traits of greater importance to our research. For instance, we can remove variables that include income, zip code, tuition, and etc. for variables that we want to delve into for our question and hypothesis such as race, career, activities, and field of study.
#
# ---
#
# This dataset is not the ideal for our research question as it places limitations to specifically the population at Columbia University in New York. We were hoping to gather more information on speed dating preferences regarding the United States as a whole. When looking for other datasets to expand on our research questions, datasets became scarce as not many studies have been conducted for speed dating and some datasets obtained from online dating sites were against the companies’ Terms of Service due to lack of complete anonymity. However, we can still obtain some information that could help us gain insight on dating for those in college, since it is often a time in many people’s lives to introduce them to opportunities they want for the foreseeable future (e.g. career goals, field of study, interests, etc.).

# %% [markdown]
# ## **Setup**

# %%
# Imported packages used to create the dataset
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import csv
import io

import statsmodels.api as sm

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import metrics

from scipy import stats


import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ##**Data Cleaning**
#
# To clean this dataset, we eliminated variables that were outside the scope of our research question, since the dataset was expansive to begin with. We discovered that in our dataset, participants may appear multiple times due to their potential matches. Therefore, we filtered out and got rid of data from duplicate participants and also any rows that have missing data. Furthermore, we modified the initial representations of results for clarity (for instance, a value of '0' in a certain category corresponded to an answer of 'No', so we converted '0' to 'No'). Many of the operations we performed were of this "housekeeping" nature.
#
# Minor tweaks, as previously described, were done to make future data analysis easier. We didn't have to standardize any data because the participants had a specific number to choose from for the longer answers. So we had to transform their values to the code provided to us to transfigure it.
#
# Certain variables in the dataset such as the various attributes and activities is a rating from 1-10 of how important or interested they are in that variable in their partner.

# %% [markdown]
# **Dataset:** Speed Dating dataset
#
# Importing the data to create the table:

# %%
# Assign a variable to the speed dating data file to be read 
dataURL = "https://raw.githubusercontent.com/COGS108/group088_wi21/main/Speed%20Dating%20Dataset/SpeedDatingComplete.csv?token=ALXEC7VLCSPNKTWKGKFGOILALGOPS"
speedDating_df = pd.read_csv(dataURL)

# Take a look at the original dataset
speedDating_df.head()
# Out:
#    iid   id  gender  idg  condtn  ...  attr5_3  sinc5_3  intel5_3  fun5_3  amb5_3
# 0    1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 1    1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 2    1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 3    1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 4    1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
#
# [5 rows x 195 columns]

# %% [markdown]
# The initial dataset is a bit messy... let's clean it up by simplifying our dataset to variables that we're gonna take a closer look at. We'll also change the names of the variables so it's easier for us to understand.

# %%
# specify certain variables to include
speedDating_df = speedDating_df[['iid','gender', 'match','int_corr', 'age_o', 'samerace', 'race_o', 
                                 'imprace', 'imprelig', 'goal', 'dec_o', 'attr_o', 'sinc_o', 'intel_o', 'fun_o', 'amb_o', 'shar_o',
                                 'sports', 'tvsports', 'exercise', 'dining', 'museums', 'art', 'hiking', 
                                 'clubbing', 'reading', 'tv', 'theater', 'movies', 'concerts', 'music', 'shopping', 'yoga']]

#change column variable names to have easier understanding
speedDating_df.rename(columns={'iid':'Unique identifier'}, inplace=True)
speedDating_df.rename(columns={'gender':'Gender'}, inplace=True)
speedDating_df.rename(columns={'match':'Match?'}, inplace=True)
speedDating_df.rename(columns={'int_corr':'Correlation of interests'}, inplace=True)
speedDating_df.rename(columns={'age_o':'Age of partner'}, inplace=True)
speedDating_df.rename(columns={'samerace':'Same race?'}, inplace=True)
speedDating_df.rename(columns={'race_o':'Race of partner'}, inplace=True)
speedDating_df.rename(columns={'imprace':'Importance of race'}, inplace=True)
speedDating_df.rename(columns={'imprelig':'Importance of religion'}, inplace=True)
speedDating_df.rename(columns={'goal':'Goal'}, inplace=True)
speedDating_df.rename(columns={'dec_o':'Meet partner again?'}, inplace=True)
speedDating_df.rename(columns={'attr_o':'Attractiveness'}, inplace=True)
speedDating_df.rename(columns={'sinc_o':'Sincerity'}, inplace=True)
speedDating_df.rename(columns={'intel_o':'Intelligence'}, inplace=True)
speedDating_df.rename(columns={'fun_o':'Humor'}, inplace=True)
speedDating_df.rename(columns={'amb_o':'Ambition'}, inplace=True)
speedDating_df.rename(columns={'shar_o':'Shared Interests'}, inplace=True)
speedDating_df.rename(columns={'tvsports':'tv sports'}, inplace=True)

# %% [markdown]
# Now let's replace the values for "Same race?", "Match?", "Meet partner again?" and "Gender" columns. We're gonna replace the values with the corresponding values given to us from the dataset variable key.

# %%
#replaces current '0' & '1' values with 'Yes' & 'No' where appropriate
speed_bool = speedDating_df['Same race?'].replace({0: 'No', 1: 'Yes'})
speedDating_df['Same race?'] = speed_bool.replace({0: 'No', 1: 'Yes'})

speed_bool = speedDating_df['Match?'].replace({0: 'No', 1: 'Yes'})
speedDating_df['Match?'] = speed_bool.replace({0: 'No', 1: 'Yes'})

speed_bool = speedDating_df['Meet partner again?'].replace({0: 'No', 1: 'Yes'})
speedDating_df['Meet partner again?'] = speed_bool.replace({0: 'No', 1: 'Yes'})

#replaces current '0' & '1' values in the gender column with appropriate gender
speed_bool = speedDating_df['Gender'].replace({0: 'Female', 1: 'Male'})
speedDating_df['Gender'] = speed_bool.replace({0: 'Female', 1: 'Male'})

# %% [markdown]
# Next, we're gonna replace the values for "Race of partner", "Goal", and "How frequent do you go on dates?" so that the values make more sense. Each number corresponds with a specific value.

# %%
#Replaces values of race column using the code provided
speed_race = speedDating_df['Race of partner'].replace({1.0: 'Black/African American', 2.0: 'White', 3.0: 'Latino/Hispanic', 
                                                        4.0: 'Asian/Pacific Islander', 5.0: 'Native American', 6.0: 'Other'})
speedDating_df['Race of partner'] = speed_race.replace({1.0: 'Black/African American', 2.0: 'White', 3.0: 'Latino/Hispanic', 
                                                        4.0: 'Asian/Pacific Islander', 5.0: 'Native American', 6.0: 'Other'})

# %%
#Replaces values of subject's goal column using the code provided
speed_goal = speedDating_df['Goal'].replace({1.0: 'Seemed like a fun night out', 2.0: 'To meet new people', 
                                                        3.0: 'To get a date', 4.0: 'Looking for a serious relationship', 
                                                        5.0: 'To say I did it', 6.0: 'Other'})
speedDating_df['Goal'] = speed_goal.replace({1.0: 'Seemed like a fun night out', 2.0: 'To meet new people', 
                                                        3.0: 'To get a date', 4.0: 'Looking for a serious relationship', 
                                                        5.0: 'To say I did it', 6.0: 'Other'})

# %%
#check for repeated participants 
check_id = speedDating_df['Unique identifier'].duplicated().any()
print(check_id)
# Out:
# True

# %% [markdown]
# Since participants show up multiple times in the dataset, we have to update our current dataset with unique individuals to get rid of repetitive data to avoid bias in our data.

# %%
#remove duplications and only keep one data from each participant
speedDating_df = speedDating_df.drop_duplicates(subset=['Unique identifier'])
speedDating_df.head
# Out:
# <bound method NDFrame.head of       Unique identifier  Gender Match?  ...  music  shopping yoga
# 0                     1  Female     No  ...    9.0       8.0  1.0
# 10                    2  Female     No  ...    8.0       3.0  1.0
# 20                    3  Female     No  ...    5.0       8.0  7.0
# 30                    4  Female     No  ...    7.0       1.0  8.0
# 40                    5  Female     No  ...    7.0       8.0  3.0
# ...                 ...     ...    ...  ...    ...       ...  ...
# 8268                548    Male    Yes  ...   10.0       4.0  1.0
# 8290                549    Male     No  ...   10.0       8.0  2.0
# 8312                550    Male     No  ...    6.0       6.0  3.0
# 8334                551    Male     No  ...    7.0       7.0  1.0
# 8356                552    Male    Yes  ...   10.0       7.0  3.0
#
# [551 rows x 33 columns]>

# %%
#Drops rows with missing data
dropped_rows = speedDating_df.dropna(subset = ["Importance of race", "Importance of religion", "Correlation of interests", "Attractiveness",
                                               "Sincerity", "Intelligence", "Humor", "Ambition", "Shared Interests"],inplace=True)

dropped_rows = speedDating_df.isnull().sum()
print(dropped_rows)
# Out:
# Unique identifier           0
# Gender                      0
# Match?                      0
# Correlation of interests    0
# Age of partner              0
# Same race?                  0
# Race of partner             0
# Importance of race          0
# Importance of religion      0
# Goal                        0
# Meet partner again?         0
# Attractiveness              0
# Sincerity                   0
# Intelligence                0
# Humor                       0
# Ambition                    0
# Shared Interests            0
# sports                      0
# tv sports                   0
# exercise                    0
# dining                      0
# museums                     0
# art                         0
# hiking                      0
# clubbing                    0
# reading                     0
# tv                          0
# theater                     0
# movies                      0
# concerts                    0
# music                       0
# ...

# %% [markdown]
# Our data set no longer has any pertinent data that's missing.

# %%
#Check new data frame after all the cleaning
speedDating_df
# Out:
#       Unique identifier  Gender Match?  ...  music  shopping yoga
# 0                     1  Female     No  ...    9.0       8.0  1.0
# 10                    2  Female     No  ...    8.0       3.0  1.0
# 20                    3  Female     No  ...    5.0       8.0  7.0
# 30                    4  Female     No  ...    7.0       1.0  8.0
# 40                    5  Female     No  ...    7.0       8.0  3.0
# ...                 ...     ...    ...  ...    ...       ...  ...
# 8246                547    Male     No  ...    9.0       6.0  5.0
# 8268                548    Male    Yes  ...   10.0       4.0  1.0
# 8290                549    Male     No  ...   10.0       8.0  2.0
# 8312                550    Male     No  ...    6.0       6.0  3.0
# 8334                551    Male     No  ...    7.0       7.0  1.0
#
# [489 rows x 33 columns]

# %% [markdown]
# Our dataset is a lot easier to look at now!

# %% [markdown]
# ##**Data Analysis & Results (EDA)**
# For our exploratory data analysis, we are going to analyze our variables to understand their relationship by themselves and with one another.
#
# ##*Preliminary Thoughts*
# ##Structure
# As a result of the data cleaning we carried out, our data's now in a tabular format, with each observation in a separate row. Having removed data outside the scope of our analysis and consolidated all the variables we need into a single dataframe, we're now ready to carry out further analysis.
# ##Granularity
# Each row of the dataframe represents a single individual and their responses, and we intend to analyze relationships between variables we chose, like race and gender (in line with our research question).
# ##Scope
# At this point, we've narrowed the dataset down to roughly 489 individuals and their associated data.
# ##Temporality
# Time-related analysis is outside the scope of our project. The original data-set did not collect time-related data, and we decided not to include it as a factor since the only time-related variable we would have considered (length of the interview) remained constant. For reference, however, the dataset we used was conducted from 2002-2004, and the length of each speed-date was four minutes.
# ##Faithfulness
# Mostly our data looks to be quite reliable. There aren't any weird outliers, and we've already ironed out all the inconsistent data. The data also comes from a reputable source to begin with (the Columbia Business School, via Kaggle).

# %% [markdown]
# ##As a reminder, we're looking to answer the following questions:
# * How does a person’s racial background and personal qualities such as religion affect their desirability as a potential partner?
# * Do factors such as similar characteristics (i.e. personality traits, interests) make a more positive first impression, therefore increasing the likelihood of attraction?
# * Are females or males more likely to secure a date?

# %% [markdown]
# ### So how does a person’s racial background and personal qualities such as religion affect their desirability as a potential partner?

# %% [markdown]
# **Race Distribution**
#
# We wanted to explore the race distribution among this speed dating dataset.

# %%
sns.set(font_scale=1.5)
sns.set_palette("pastel")

race_dist = sns.countplot(x="Race of partner", data=speedDating_df)
race_dist.set_xlabel('Race')
race_dist.set_ylabel('Count')
race_dist.set_title("Race Distribution")
race_dist.set_xticklabels(race_dist.get_xticklabels(), rotation=40, ha="right")



print(speedDating_df['Race of partner'].value_counts())
# Out:
# White                     237
# Asian/Pacific Islander    190
# Latino/Hispanic            36
# Other                      26
# Name: Race of partner, dtype: int64

# %% [markdown]
# From our visual above, it's quite clear that the distribution of race among our dataset is skewed pretty heavily towards White and Asian people. Unfortunately, these demographics are not representative of the entire United States, but rather a small subsection of New York since our dataset pertains to students at Columbia University.

# %% [markdown]
# Let's see if individuals value racial preferences in their potential partners.

# %%
solo_race = speedDating_df['Importance of race'].hist(bins=10, figsize=(10,10))
solo_race.set_title('How Important is Race to you?')
solo_race.set_xlabel('Rating')
solo_race.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Overall, race is not deemed important to many of the participants.

# %% [markdown]
# Let's explore if there's a gender difference in the ratings.

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.set(font_scale=1.3)
sns.set_palette("pastel")

#generate plot
ax = sns.boxplot(x='Gender', y='Importance of race', data=speedDating_df)
ax = sns.stripplot(x='Gender', y='Importance of race', data=speedDating_df, color=".25")

#customize plot
ax.set_title('How Important is Race?, by Gender ')
ax.set_xlabel('Gender')
ax.set_ylabel('Rating of Race Importance')
# Out:
# Text(0, 0.5, 'Rating of Race Importance')

# %% [markdown]
# Between the genders, females and males have about the same mean rating of race importance. However, women have more variety in their ratings and have more high scorers. About 75% of women rated higher than 3 for how important they believe the race of their potential partner is. For men, there is less variety in their ratings so it's possible that men don't care that much about race of their partner.

# %%
#take a closer look
speedDating_df[['Gender', 'Importance of Race']].groupby(['Gender']).agg(['mean', 'median', 'min', 'max', 'count'])
# Out:
#        Importance of race
#                      mean median  min   max count
# Gender
# Female           4.110672    3.0  0.0  10.0   253
# Male             3.398305    3.0  1.0  10.0   236

# %% [markdown]
# From our data above, we can see that females are more likely than men to believe race is an important factor to desirability in a potential partner. However, the mean ratings for both genders are relatively low so there's not a big difference.

# %% [markdown]
# Let's explore the relationship between same racial identity as partner and the destire to match.

# %%
sns.set(font_scale=1.5)
sns.set_palette("pastel")


same_stacked = speedDating_df.groupby(['Meet partner again?','Same race?'])['Meet partner again?'].count().unstack('Same race?').fillna(0)
same_stacked2 = np.transpose(same_stacked.div(same_stacked.sum()))

#generate plot
same_match = same_stacked2.plot(kind='barh', stacked=True, rot=0,
                  title='Desire to Match among Interracial Partners')

#customize plot
same_match.set_xlabel('Proportion')
same_match.set_ylabel('Same race as partner?')
same_match.legend(('No','Yes'), loc='center left', bbox_to_anchor=(1.0, 0.5), title = 'Desire to match?')

# %% [markdown]
# When comparing matches between partners of the same or different race shows, it is shown that generally people will look for similar racial backgrounds when searching for a potential partner. In the chart above, there was more desirability of partners when they were of the same race and less desire to match if they were not of the same raccial background.

# %% [markdown]
# **Religion**
#
# Next, we wanted to see if individuals valued religious preferences in their potential partners.

# %%
solo_religion = speedDating_df['Importance of religion'].hist(bins=10, figsize=(10,10))
solo_religion.set_title('How Important is Religion to you?')
solo_religion.set_xlabel('Rating')
solo_religion.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# From the graph above, it seems like individuals don't care too much about their partner's religion.

# %% [markdown]
# Now let's compare religion importance among different races when it comes to desirability for a potential partner.

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.set(font_scale=1.3)
sns.set_palette("pastel")

#generate plot
ax = sns.boxplot(x='Gender', y='Importance of religion', data=speedDating_df)
ax = sns.stripplot(x='Gender', y='Importance of religion', data=speedDating_df, color=".25")

#customize plot
ax.set_title('How Important is Religion?, by Gender')
ax.set_xlabel('Gender')
ax.set_ylabel('Rating of Religion Importance')
# Out:
# Text(0, 0.5, 'Rating of Religion Importance')

# %% [markdown]
# There are variable differences between gender and the the rating of religion importance. On average, women tend to rate importance of religion higher than their male counterparts. However, the mean rating of both genders is relatively low.

# %% [markdown]
# Based on individual's ratings of religion importance, let's explore the relationship between the proportion of those that desire to match and the rating that they gave.

# %%
sns.set(font_scale=1.5)
sns.set_palette("pastel")


religion_stacked = speedDating_df.groupby(['Meet partner again?','Importance of religion'])['Meet partner again?'].count().unstack('Importance of religion').fillna(0)
religion_stacked2 = np.transpose(religion_stacked.div(religion_stacked.sum()))

#generate plot
religion_match = religion_stacked2.plot(kind='bar', stacked=True, rot=0,
                  title='Religion Importance')

#customize plot
religion_match.set_xlabel('Rating of Importance')
religion_match.set_ylabel('Proportion')
religion_match.legend(('No','Yes'), loc='center left', bbox_to_anchor=(1.0, 0.5), title = 'Desire to match?')

# %% [markdown]
# From the graph above, those who rated religion as highly important had less desire to match with others compared to those who rated religion as less important.

# %% [markdown]
# ### Do factors such as similar characteristics (i.e. personality traits, interests) make a more positive first impression, therefore increasing the likelihood of attraction?

# %% [markdown]
# ### **Personality Traits**
# Next, we are going to see if certain characteristics will affect one's desire to match.

# %% [markdown]
# **Attractiveness**

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.set(font_scale=1.3)
sns.set_palette("bright")

# generate grouped barplot by specifying hue
attr = sns.countplot(x='Attractiveness', hue='Meet partner again?',
                   data=speedDating_df)

# add title and axis labels (modify x-axis label)
attr.set_title('Attractiveness')
attr.set_ylabel('Count')
attr.set_xlabel('Rating')
attr.legend(('No','Yes'), loc='center left', bbox_to_anchor=(1.0, 0.5), title = 'Desire to match?')

# %% [markdown]
# Let's determine the p-value to see if there is a statistical significance between rating of attractiveness and the desired matches.

# %%
# chi-square test to determine association between desire to match and attractiveness
chi_attr = pd.crosstab(speedDating_df['Attractiveness'], speedDating_df['Meet partner again?'])
print(chi_attr)
attr_table = sm.stats.Table(chi_attr)
attr_match_result = attr_table.test_nominal_association()
print(attr_match_result)
# Out:
# Meet partner again?  No  Yes
# Attractiveness
# 0.0                   2    0
# 1.0                   7    1
# 2.0                  20    2
# 3.0                  14    2
# 4.0                  35    5
# 5.0                  61   25
# 6.0                  47   22
# 7.0                  52   34
# 8.0                  28   46
# 9.0                  10   39
# 9.5                   1    0
# 10.0                 12   24
# df          11
# pvalue      5.662137425588298e-15
# statistic   92.40710931158043

# %% [markdown]
# From the results of our chi-square test, there is a statisically significant difference between attractiveness and getting a match because our p-value is quite obviously below both the standard alphas of 0.05 and 0.01, meaning the chance of this occuring randomly is next to impossible. So we can infer that attraction plays a role in desirability of a potential partner.

# %% [markdown]
# **Sincerity**

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.set(font_scale=1.3)
sns.set_palette("bright")

# generate grouped barplot by specifying hue
attr = sns.countplot(x='Sincerity', hue='Meet partner again?',
                   data=speedDating_df)

# add title and axis labels (modify x-axis label)
attr.set_title('Sincerity')
attr.set_ylabel('Count')
attr.set_xlabel('Rating')
attr.legend(('No','Yes'), loc='center left', bbox_to_anchor=(1.0, 0.5), title = 'Desire to match?')

# %% [markdown]
# **Intelligence**

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.set(font_scale=1.3)
sns.set_palette("bright")

# generate grouped barplot by specifying hue
attr = sns.countplot(x='Intelligence', hue='Meet partner again?',
                   data=speedDating_df)

# add title and axis labels (modify x-axis label)
attr.set_title('Intelligence')
attr.set_ylabel('Count')
attr.set_xlabel('Rating')
attr.legend(('No','Yes'), loc='center left', bbox_to_anchor=(1.0, 0.5), title = 'Desire to match?')

# %% [markdown]
# **Humor**

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.set(font_scale=1.3)
sns.set_palette("bright")

# generate grouped barplot by specifying hue
attr = sns.countplot(x='Humor', hue='Meet partner again?',
                   data=speedDating_df)

# add title and axis labels (modify x-axis label)
attr.set_title('Humor')
attr.set_ylabel('Count')
attr.set_xlabel('Rating')
attr.legend(('No','Yes'), loc='center left', bbox_to_anchor=(1.0, 0.5), title = 'Desire to match?')

# %% [markdown]
# **Ambition**

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.set(font_scale=1.3)
sns.set_palette("bright")

# generate grouped barplot by specifying hue
attr = sns.countplot(x='Ambition', hue='Meet partner again?',
                   data=speedDating_df)

# add title and axis labels (modify x-axis label)
attr.set_title('Ambition')
attr.set_ylabel('Count')
attr.set_xlabel('Rating')
attr.legend(('No','Yes'), loc='center left', bbox_to_anchor=(1.0, 0.5), title = 'Desire to match?')

# %% [markdown]
# When looking at the graphs for the characteristics above, you can see that as the ratings go up, individuals have more of a desire to match. However, it seems like humor was the trait that corresponded most strongly with the desire to match and you can see that at the rating of 8.0. It just goes to show that having similar characteristics increases the desire to match with a potential partner.

# %% [markdown]
# ### **Interests & Hobbies**
# Now we are going to see if having similar interests/hobbies will influence an individual's desire to match.

# %%
#convert sns color palette to use for matplotlib
my_cmap = sns.set_palette("bright")

interests = ['sports', 'tv sports', 'exercise', 'dining', 'museums', 'art', 'hiking',
             'clubbing', 'reading', 'tv', 'theater', 'movies', 'concerts', 'music', 'shopping', 'yoga']	


#generate grouped barplot
gender_interests = speedDating_df[['Gender']+ interests].groupby(['Gender']).mean().stack().unstack(0)
gender_interests = gender_interests.plot(kind='bar', figsize=(10,10), cmap=my_cmap)
gender_interests.set_xticklabels(gender_interests.get_xticklabels(), fontsize=12, rotation=45)


#add title and axis labels
gender_interests.set_title('Interest in Hobbies by Gender', fontsize=18)
gender_interests.set_ylabel('Rating')
gender_interests.set_xlabel('Hobbies')
gender_interests.legend(('Female','Male'), loc='center left', bbox_to_anchor=(1.0, 0.5), title = 'Gender')

# %% [markdown]
# On average, the female participants gave higher ratings for their interests in specified hobbies compared to their male counterparts. The only interests where females have a lower rating are sports and tv sports.

# %% [markdown]
# **Shared Interests**

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.set(font_scale=1.3)
sns.set_palette("bright")

# generate grouped barplot by specifying hue
attr = sns.countplot(x='Shared Interests', hue='Meet partner again?',
                   data=speedDating_df)

# add title and axis labels (modify x-axis label)
attr.set_title('Shared Interests')
attr.set_ylabel('Count')
attr.set_xlabel('Rating')
attr.legend(('No','Yes'), loc='center left', bbox_to_anchor=(1.0, 0.5), title = 'Desire to match?')

# %% [markdown]
# As you can see, as the rating for shared interests/hobbies increases, there is significantly more desire to match, with the ratings 6-7 having the most desire to see their partner again.

# %% [markdown]
# ### Are females or males more likely to secure a date?

# %% [markdown]
# **Gender Distribution**

# %%
sns.set(font_scale=1.5)
sns.set_palette("Set2")

race_dist = sns.countplot(x="Gender", data=speedDating_df)
race_dist.set_xlabel('Gender')
race_dist.set_ylabel('Count')
race_dist.set_title("Gender Distribution")

print(speedDating_df['Gender'].value_counts())
# Out:
# Female    253
# Male      236
# Name: Gender, dtype: int64

# %% [markdown]
# From the figure above, there is a rough equal distribution of gender among this dataset. There are 236 male participants and 253 female participants.
#
# Let's see how many matches both genders get.

# %%
sns.set(font_scale=1.5)
sns.set_palette("Set2")


gender_stacked = speedDating_df.groupby(['Match?','Gender'])['Match?'].count().unstack('Gender').fillna(0)
gender_stacked2 = np.transpose(gender_stacked.div(gender_stacked.sum()))

#generate plot
gender_match = gender_stacked2.plot(kind='bar', stacked=True, rot=0,
                  title='Successful Matches among Genders')

#customize plot
gender_match.set_xlabel('Gender')
gender_match.set_ylabel('Proportion')
gender_match.legend(('No match','Match'), loc='center left', bbox_to_anchor=(1.0, 0.5), title = 'Successful match?')

# %% [markdown]
# Although there is not much of a difference between the females and males, it seems like males were able to secure more matches than females.

# %%
#chi-square test on matches between gender
chi_gender = pd.crosstab(speedDating_df['Gender'], speedDating_df['Meet partner again?'])
print(chi_gender)
chi_table = sm.stats.Table(chi_gender)
chi_gender_result = chi_table.test_nominal_association()
print(chi_gender_result)
# Out:
# Meet partner again?   No  Yes
# Gender
# Female               147  106
# Male                 142   94
# df          1
# pvalue      0.6422867328482071
# statistic   0.21576391611030693

# %% [markdown]
# For our chi-square test, we measured gender and responses to the question, "Would you like to see them again?" From the results of our chi-square test, we failed to reject the null hypothesis, meaning that we could not confirm nor deny a link between gender and successful matching. So what this means is that females aren't necessarily more desired than males like we hypothesized in the beginning.

# %% [markdown]
# ##**Ethics & Privacy**
# **Ethical Concerns:**
# *   For privacy, there were no concerns to participants as they were not permitted access to any other participants’ contact information prior to the start of the study and were only released if a matched pairing both accepted wanting to meet each other again. In this case, both sides of the pairing would have to express their consent to the team conducting the experiment.
#    *   In terms of personally identifiable information such as name, email addresses, and school ID numbers, all remained anonymous throughout the experiment.
#
# **Potential Bias:**
# *   Given that our dataset is pertaining to students at Columbia University, there is possible bias for partner preferences.
#   *   Regarding ethnic backgrounds, a majority of students at the school are Caucasian/White and may produce bias in racial preference. Unfortunately, these demographics are not representative of the entire United States, but rather an area of New York.
#   * Also, the people who participated in these speed-dating events tended to be younger, college-educated, and urban. This strongly limits the potential predictive power for the conclusions we reached in our analysis.

# %% [markdown]
# ##**Conclusion & Discussion**
# **Takeaways from our Data Analysis:**
# * An individual’s racial background has a small effect on their desirability as a potential partner
# * Religious affiliation has no effect on desirability at all
# * Attraction, Humor, and shared interests all played a role in securing a match and desirability for potential partners
# * Males are able to secure more dates than females, but not statistically different
#
# **Limitations on our analysis:**
# * limited age range
# * data consists of only heterosexual relationships
# * observservations of only college students
# * majority of our participants are white, which is not representative of the whole population
# * dataset is old so preferences may be outdated or have changed.
#
# Overall, our data analysis was able to answer all of our research questions clearly, such as how an individual's racial background has a small effect on desirability and that religion did not effect desirability at all.
#
# As for our hypothesis, we were able to prove that a person's physical attractiveness and similar interests affected desirability; however, gender did not really matter at all when it came to the who was more desired.

# %% [markdown]
# ##**Team Contributions**
#
#
# *   Lisa Dang:
#   * Found topic, dataset & references
#   * Prior Research
#   * Privacy & Ethics Considerations
#   * Presentation Slides
#   * Audio Recording
#   * Video edit
#
#
# *   Danny Ha:
#   * Overview
#   * Conclusion & Discussion
#   * Data Analysis
#   * Presentation Slides
#   * Audio Recording
#
# *   Justin Le:
#   * Data Analysis
#   * Proofreading
#   * Presentation Slides
#   * Audio Recording
#
# *   Destynee Tau:
#   * Data Analysis
#   * Presentation Slides
#   * Audio Recording
#
# *   Pauline Thach:
#   * Background & Prior Research
#   * Data Cleaning/Wrangling
#   * Data Visualizations (EDA)
#   * Data Analysis
#   * Audio Recording
