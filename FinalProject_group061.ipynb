# %% [markdown]
# # COGS 108 - Can money buy happiness?

# %% [markdown]
# # Overview

# %% [markdown]
# Can money buy you happiness? To elaborate, we wondered whether government spending across different countries affects citizen's happiness/life satisfaction. We used data from OECD's reports (Organisation for Economic Co-operation and Development) and proceeded with data analysis on our final dataframe. We concluded that the U.S. doesn't spend that much differently that the other 5 happiest countries.

# %% [markdown]
# # Names
#
# - Mylinh Lac
# - Kelly Li
# - Braeanne Oribello
# - Theodore Nguyen
# - Erika Koh

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# How does government spending in the US differ from government spending in happier nations?

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# The World Happiness Report, created by the UN every year, reports the perceived happiness of the people in different countries using a life evaluation survey. In order to predict which countries are the happiest, the report uses several factors including: GDP per capita, social support, healthy life expectancy, freedom to make life choices, generosity, and corruption. Looking at all of these different factors that together form a predictor of life evaluation scores within a given country, it’s been found that government spending on aspects such as allocation to welfare heavily influence scores on life satisfaction (WHR 2020). The reason for this could be that citizens trust and depend on their government more in these countries to financially support them in times of strife or otherwise unexpected circumstances. This could be the case for the Nordic countries that consistently rank high within the World Happiness Report.
# 	Additionally, there has been speculation that when citizens in the United States feel they can see tangible progress for the public that is directly funded by their tax dollar, they are likely to report higher life satisfaction as well as satisfaction with their respective government (Jacobs 2018). Perhaps this can be generalized to other countries as well, and so it depends on the governments’ decisions in terms of what sectors and projects they go on to utilize citizens’ money for.
#
#
# References (include links):
# - 1) https://worldhappiness.report/
# - 2) https://worldhappiness.report/blog/its-a-three-peat-finland-keeps-top-spot-as-happiest-country-in-world/

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We hypothesize that the US will be an outlier in more spending categories than the countries ranked highest in the 2017 World Happiness Report (Norway, Denmark, Iceland, Switzerland, Finland). To measure outliers for each spending category, we will use the Interquartile Range Rule (IQR*1.5). In comparison to the above countries, the US was ranked much lower in the 2017 World Happiness Report (#14). The way a government invests its money can greatly influence the resources that its citizens have and therefore the satisfaction of its citizens. We think that the US invested its money very differently than happier countries which played a role in the US not being able to maximize citizen happiness.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - Dataset Name: General Government Spending
# - Link to the dataset: https://data.oecd.org/gga/general-government-spending.htm
# - Number of observations: 60 Observations
#
# We pulled our datasets from the Organisation for Economic Co-operation and Development website, and we were able to get government spending data on the top 5 happiest countries (based on the World Happiness Report from 2017) along with the United States. These datasets were divided into these following categories: Defence, Economic Affairs, Education, Environmental Protection, General Services, Health, Housing, Public Safety, Recreation, and Social Protection. The values are how much they spent based on percentages of each country’s GDP.
#
# We took multiple datasets from one data sets with multiple perspectives such as Education, Housing, Health, Public Safety, etc. We plan on dropping all the unnecessary columns in each of the csv files and then combining them together by columns in one big dataset.

# %% [markdown]
# # Setup

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# To attain a usuable dataframe, we first removed all the unnecessary columns from the csv files. To do this, we removed the columns that don't contain our target year (2017) or our target countries (top 5 happiest and the U.S.). We then compiled it into a readable dataframe.

# %%
# importing dataframes
defence_df = pd.read_csv("Defence_Countries.csv")
econ_df = pd.read_csv("EconomicAffairs_Countries.csv")
edu_df = pd.read_csv("Education_Countries.csv")
enviro_df = pd.read_csv("Environmental_Countries.csv")
gen_df = pd.read_csv("GeneralServices_Countries.csv")
health_df = pd.read_csv("Health_Countries.csv")
housing_df = pd.read_csv("Housing_Countries.csv")
psafety_df = pd.read_csv("PublicSafety_Countries.csv")
rec_df = pd.read_csv("Recreation_Countries.csv")
sprotect_df = pd.read_csv("SocialProtection_Countries.csv")
total_df = pd.read_csv("Total_Spending_Countries.csv")

# %%
# dropping unnecessary columns
defence_df = defence_df.drop(columns=["INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY","Flag Codes"])
econ_df = econ_df.drop(columns=["INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY","Flag Codes"])
edu_df = edu_df.drop(columns=["INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY","Flag Codes"])
enviro_df = enviro_df.drop(columns=["INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY","Flag Codes"])
gen_df = gen_df.drop(columns=["INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY","Flag Codes"])
health_df = health_df.drop(columns=["INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY","Flag Codes"])
housing_df = housing_df.drop(columns=["INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY","Flag Codes"])
psafety_df = psafety_df.drop(columns=["INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY","Flag Codes"])
rec_df = rec_df.drop(columns=["INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY","Flag Codes"])
sprotect_df = sprotect_df.drop(columns=["INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY","Flag Codes"])
total_df = total_df.drop(columns=["INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY","Flag Codes"])

# %%
#testing enviro_df
enviro_df
# Out:
#     LOCATION  TIME     Value
# 0        SVN  2016  0.563333
# 1        SVN  2017  0.452764
# 2        SVN  2018  0.530629
# 3        JPN  2016  1.183260
# 4        JPN  2017  1.156646
# ..       ...   ...       ...
# 96       LTU  2017  0.413281
# 97       LTU  2018  0.313556
# 98       CHL  2016  0.215780
# 99       CHL  2017  0.218934
# 100      CHL  2018  0.204781
#
# [101 rows x 3 columns]

# %%
# only preserve data from 2017
defence_df = defence_df[defence_df.TIME == 2017]
defence_df = defence_df.reset_index(drop = True)

econ_df = econ_df[econ_df.TIME == 2017]
econ_df = econ_df.reset_index(drop = True)

edu_df = edu_df[edu_df.TIME == 2017]
edu_df = edu_df.reset_index(drop = True)

enviro_df = enviro_df[enviro_df.TIME == 2017]
enviro_df = enviro_df.reset_index(drop = True)

gen_df = gen_df[gen_df.TIME == 2017]
gen_df = gen_df.reset_index(drop = True)

health_df = health_df[health_df.TIME == 2017]
health_df = health_df.reset_index(drop = True)

housing_df = housing_df[housing_df.TIME == 2017]
housing_df = housing_df.reset_index(drop = True)

psafety_df = psafety_df[psafety_df.TIME == 2017]
psafety_df = psafety_df.reset_index(drop = True)

rec_df = rec_df[rec_df.TIME == 2017]
rec_df = rec_df.reset_index(drop = True)

sprotect_df = sprotect_df[sprotect_df.TIME == 2017]
sprotect_df = sprotect_df.reset_index(drop = True)

total_df = total_df[total_df.TIME == 2017]
total_df = total_df.reset_index(drop = True)

# %%
# testing econ_df
econ_df
# Out:
#    LOCATION  TIME     Value
# 0       FRA  2017  5.878963
# 1       LUX  2017  5.588373
# 2       CHE  2017  3.821272
# 3       POL  2017  4.818221
# 4       ITA  2017  4.081222
# 5       PRT  2017  5.270996
# 6       IRL  2017  2.168404
# 7       SWE  2017  4.184283
# 8       ISL  2017  4.500083
# 9       DNK  2017  3.251587
# 10      DEU  2017  3.205905
# 11      BEL  2017  6.439567
# 12      NOR  2017  5.669631
# 13      ISR  2017  2.631185
# 14      EST  2017  4.693234
# 15      USA  2017  3.360048
# 16      AUT  2017  5.817344
# 17      SVK  2017  5.433149
# 18      HUN  2017  7.304561
# 19      CZE  2017  5.759339
# 20      SVN  2017  4.287067
# 21      GBR  2017  3.219566
# 22      FIN  2017  4.294723
# 23      GRC  2017  3.699650
# 24      NLD  2017  3.811170
# 25      ESP  2017  3.860166
# 26      KOR  2017  4.473056
# 27      JPN  2017  3.621578
# 28      AUS  2017  4.897217
# 29      LVA  2017  5.547049
# 30      COL  2017  3.067234
# 31      CRI  2017  3.181830
# ...

# %%
# drops rows with countries we don't need
#NOR = norway
#DNK = denmark
#ISL = iceland
#CHE = switerzerland
#FIN = finland
#USA = united states of america
defence_df = defence_df[defence_df["LOCATION"].isin(["NOR","DNK","ISL","CHE","FIN","USA"])]
defence_df = defence_df.reset_index(drop = True)

econ_df = econ_df[econ_df["LOCATION"].isin(["NOR","DNK","ISL","CHE","FIN","USA"])]
econ_df = econ_df.reset_index(drop = True)

edu_df = edu_df[edu_df["LOCATION"].isin(["NOR","DNK","ISL","CHE","FIN","USA"])]
edu_df = edu_df.reset_index(drop = True)

enviro_df = enviro_df[enviro_df["LOCATION"].isin(["NOR","DNK","ISL","CHE","FIN","USA"])]
enviro_df = enviro_df.reset_index(drop = True)

gen_df = gen_df[gen_df["LOCATION"].isin(["NOR","DNK","ISL","CHE","FIN","USA"])]
gen_df = gen_df.reset_index(drop = True)

health_df = health_df[health_df["LOCATION"].isin(["NOR","DNK","ISL","CHE","FIN","USA"])]
health_df = health_df.reset_index(drop = True)

housing_df = housing_df[housing_df["LOCATION"].isin(["NOR","DNK","ISL","CHE","FIN","USA"])]
housing_df = housing_df.reset_index(drop = True)

psafety_df = psafety_df[psafety_df["LOCATION"].isin(["NOR","DNK","ISL","CHE","FIN","USA"])]
psafety_df = psafety_df.reset_index(drop = True)

rec_df = rec_df[rec_df["LOCATION"].isin(["NOR","DNK","ISL","CHE","FIN","USA"])]
rec_df = rec_df.reset_index(drop = True)

sprotect_df = sprotect_df[sprotect_df["LOCATION"].isin(["NOR","DNK","ISL","CHE","FIN","USA"])]
sprotect_df = sprotect_df.reset_index(drop = True)

total_df = total_df[total_df["LOCATION"].isin(["NOR","DNK","ISL","CHE","FIN","USA"])]
total_df = total_df.reset_index(drop = True)

# %%
# rename the columns so we don't get confused when they're concatenated
defence_df.columns = ["Location", "Year", "Defence"]
econ_df.columns = ["Econ: Location", "Econ: Year", "Economic Affairs"]
edu_df.columns = ["Edu: Location", "Edu: Year", "Education"]
enviro_df.columns = ["Enviro: Location", "Enviro: Year", "Environmental"]
gen_df.columns = ["Gen: Location", "Gen: Year", "General Services"]
health_df.columns = ["Health: Location", "Health: Year", "Health"]
housing_df.columns = ["House: Location", "House: Year", "Housing"]
psafety_df.columns = ["Safety: Location", "Safety: Year", "Public Safety"]
rec_df.columns = ["Rec: Location", "Rec: Year", "Recreation"]
sprotect_df.columns = ["Social: Location", "Social: Year", "Social Protection"]
total_df.columns = ["Total: Location", "Total: Year", "Total"]

# %%
#testing defence_df
defence_df
# Out:
#   Location  Year   Defence
# 0      CHE  2017  0.797157
# 1      ISL  2017  0.057784
# 2      NOR  2017  1.703778
# 3      USA  2017  3.161583
# 4      DNK  2017  1.166460
# 5      FIN  2017  1.243477

# %%
#testing edu_df
edu_df
# Out:
#   Edu: Location  Edu: Year  Education
# 0           DNK       2017   6.428207
# 1           USA       2017   6.046674
# 2           FIN       2017   5.649997
# 3           CHE       2017   5.437640
# 4           NOR       2017   5.579384
# 5           ISL       2017   7.262576

# %%
#reorder based on happiness and USA at the bottom
reorderlist = ["NOR", "DNK", "ISL", "CHE", "FIN", "USA"]

defence_df.set_index("Location", inplace= True)
defence_df = defence_df.reindex(reorderlist)

econ_df.set_index("Econ: Location", inplace= True)
econ_df = econ_df.reindex(reorderlist)

edu_df.set_index("Edu: Location", inplace= True)
edu_df = edu_df.reindex(reorderlist)

enviro_df.set_index("Enviro: Location", inplace= True)
enviro_df = enviro_df.reindex(reorderlist)

gen_df.set_index("Gen: Location", inplace= True)
gen_df = gen_df.reindex(reorderlist)

health_df.set_index("Health: Location", inplace= True)
health_df = health_df.reindex(reorderlist)

housing_df.set_index("House: Location", inplace= True)
housing_df = housing_df.reindex(reorderlist)

psafety_df.set_index("Safety: Location", inplace= True)
psafety_df = psafety_df.reindex(reorderlist)

rec_df.set_index("Rec: Location", inplace= True)
rec_df = rec_df.reindex(reorderlist)

sprotect_df.set_index("Social: Location", inplace= True)
sprotect_df = sprotect_df.reindex(reorderlist)

total_df.set_index("Total: Location", inplace= True)
total_df = total_df.reindex(reorderlist)

# %%
#testing
defence_df
# Out:
#           Year   Defence
# Location
# NOR       2017  1.703778
# DNK       2017  1.166460
# ISL       2017  0.057784
# CHE       2017  0.797157
# FIN       2017  1.243477
# USA       2017  3.161583

# %%
# combine datasets
# this horizontally stacks them
main_df = pd.concat([defence_df, econ_df, edu_df, enviro_df, gen_df, health_df, housing_df, psafety_df, rec_df, sprotect_df, total_df], axis=1, sort=False)
main_df
# Out:
#      Year   Defence  Econ: Year  Economic Affairs  Edu: Year  Education  \
# NOR  2017  1.703778        2017          5.669631       2017   5.579384
# DNK  2017  1.166460        2017          3.251587       2017   6.428207
# ISL  2017  0.057784        2017          4.500083       2017   7.262576
# CHE  2017  0.797157        2017          3.821272       2017   5.437640
# FIN  2017  1.243477        2017          4.294723       2017   5.649997
# USA  2017  3.161583        2017          3.360048       2017   6.046674
#
#      Enviro: Year  Environmental  Gen: Year  General Services  ...  \
# NOR          2017       0.903203       2017          4.588482  ...
# DNK          2017       0.404476       2017          6.188439  ...
# ISL          2017       0.607202       2017          8.008169  ...
# CHE          2017       0.595930       2017          4.497259  ...
# FIN          2017       0.200176       2017          7.750739  ...
# ...

# %%
# drop all the year columns
main_df = main_df.drop(columns=["Econ: Year", "Edu: Year", "Enviro: Year", "Gen: Year", "Health: Year", "House: Year", "Safety: Year", "Rec: Year", "Social: Year", "Total: Year"])

# %%
# final dataframe
main_df
# Out:
#      Year   Defence  Economic Affairs  Education  Environmental  \
# NOR  2017  1.703778          5.669631   5.579384       0.903203
# DNK  2017  1.166460          3.251587   6.428207       0.404476
# ISL  2017  0.057784          4.500083   7.262576       0.607202
# CHE  2017  0.797157          3.821272   5.437640       0.595930
# FIN  2017  1.243477          4.294723   5.649997       0.200176
# USA  2017  3.161583          3.360048   6.046674       0.000000
#
#      General Services    Health   Housing  Public Safety  Recreation  \
# NOR          4.588482  8.410284  0.792017       1.158682    1.761222
# DNK          6.188439  8.323271  0.208850       0.933943    1.688540
# ISL          8.008169  7.515616  0.529619       1.437340    2.958393
# CHE          4.497259  2.097609  0.179116       1.639805    0.800018
# FIN          7.750739  7.011900  0.323463       1.126818    1.463096
# USA          5.634781  9.272449  0.544909       1.991781    0.274901
#
# ...

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# ## Structure

# %% [markdown]
# All of the datasets we are working with are in the CSV format.
#
# Each observation is in its own row, in which we concatenate the information about each country’s government spending into one main data frame that we will be analyzing.
#
# The variables we are measuring in relation to each country’s government spending is as follows: Year, Defence, Economic Affairs, Education, Environmental, General Services, Health, Housing, Public Safety, Recreation, and Social Protection.
#
# We initially were looking at several datasets, with each being a record of one of the variables across every country. The way in which we joined our tables was by first dropping columns irrelevant to our research question, extracting data specific to 2017, dropping observations for countries we were not interested in, and reordering the observations to be aligned with the ratings from the World Happiness Report. In addition, we included a column that displays the total percentage of GDP that each country spent on the different variables.

# %% [markdown]
# ##  Granularity

# %% [markdown]
# Each row is a different country which is uniform throughout the whole dataset. A row of observations represents a country’s government spending in a year. The units for the spending columns is % per GDP.  The data for spending was aggregated over one year: 2017. The final column indicates the total of government spending as % per GDP. Therefore our columns use consistent units and are aggregated identically. We plan on summarizing the data further by looking at the mean of each aspect of government spending for the happier countries and comparing that with US spending.

# %% [markdown]
# ## Scope

# %% [markdown]
# Luckily for us, we don't have any missing data since we were able to pull everything from the datasets we received. To look at the scope of our data, we are also going to be looking at the descriptive statistics and exploring visualizations to see relationships between the countries and their spending in specific categories.

# %%
main_df.isnull().any(axis=1)
# Out:
# NOR    False
# DNK    False
# ISL    False
# CHE    False
# FIN    False
# USA    False
# dtype: bool

# %% [markdown]
# ## Descriptive Statistics

# %%
main_df.describe()
# Out:
#          Year   Defence  Economic Affairs  Education  Environmental  \
# count     6.0  6.000000          6.000000   6.000000       6.000000
# mean   2017.0  1.355040          4.149557   6.067413       0.451831
# std       0.0  1.041857          0.893534   0.688192       0.321983
# min    2017.0  0.057784          3.251587   5.437640       0.000000
# 25%    2017.0  0.889483          3.475354   5.597037       0.251251
# 50%    2017.0  1.204968          4.057997   5.848336       0.500203
# 75%    2017.0  1.588703          4.448743   6.332824       0.604384
# max    2017.0  3.161583          5.669631   7.262576       0.903203
#
#        General Services    Health   Housing  Public Safety  Recreation  \
# count          6.000000  6.000000  6.000000       6.000000    6.000000
# mean           6.111311  7.105188  0.429662       1.381395    1.491028
# std            1.512812  2.574375  0.235535       0.389127    0.918958
# ...

# %% [markdown]
# ## Data Visualizations

# %%
## include Country as it's own column for plotting purposes
index=0
countries_col=['NOR','DNK','ISL','CHE','FIN','USA']
main_df.insert(loc=index, column='Country', value=countries_col)
colors = ["grey","grey", "grey", "grey","grey","red"]

# %% [markdown]
# We are going to be plotting each categorical column (Defence, Economic Affairs, etc...) to look at the differences between the spending that occurs in these different categories. We will also be able to determine which country spends the most or the least in these specfic categories.

# %%
defence = main_df.plot(x='Country', y='Defence', kind='bar', title='% of GDP Spent on Defence', color = colors)
defence.set_ylabel('% of GDP')
# Out:
# Text(0, 0.5, '% of GDP')

# %% [markdown]
# According to OECD, defence spending includes expenses on military defense, civil deviance, foreign military aid, and R&D defense. The United States spends considerably more on defence than any other country in the world. The large allocation for spending on defense is due to the goal to strengthen American security and has been used to invest in high-tech offense and defense for national security. Additionally, this increased spending was used for increasing funding to defeat ISIS and other terrorist threats as well. Since Obama’s goal and highest priority was to keep the people safe, it resulted in more spending on defence. Recently in 2019, the United States alone had spent $732 billion on national defence which is more than the total spent in 10 countries altogether.
#
# https://defense360.csis.org/wp-content/uploads/2016/08/Analysis-of-the-FY-2017-Budget.pdf
# https://www.oecd.org/gov/48250728.pdf

# %%
econ = main_df.plot(x='Country', y='Economic Affairs', kind='bar', title='% of GDP Spent on Economic Affairs', color=colors)
econ.set_ylabel('% of GDP')
# Out:
# Text(0, 0.5, '% of GDP')

# %% [markdown]
# According to OECD, spending on economic affairs includes general economic, commercial and labour affairs, agriculture, fuel and energy, communication, and transport. This also involves economic issues in both internal and external aspects in the economy and includes inflation, price control, and foreign exchange management. There is not a drastic difference between the countries for spending on economic affairs and thus, it does not seem to play a large role in the difference in the rated happiness.

# %%
edu = main_df.plot(x='Country', y='Education', kind='bar', title='% of GDP Spent on Education', color=colors)
edu.set_ylabel('% of GDP')
# Out:
# Text(0, 0.5, '% of GDP')

# %% [markdown]
# According to OECD, education spending includes spending on schools, universities and other public and private institutions. In Norway, Finland, Iceland and Denmark, tuition, even for postgraduate school, is paid for by the government. Switzerland requires some out of pocket payment but is still generally government funded. The US has the highest out of pocket cost for tuition in the world. The bart chart shows that the governments spend similarly in proportion to their GDP, ranging from about 5 to 7.5% of GDP. Denmark and Iceland spend the most at about 6.43% and 7.26%, respectively. The US follows at about 6.05%. Since the US does not spend significantly differently in % of GDP, the amount governments spend on education does not seem to play a role in the difference in rated happiness.

# %%
enviro = main_df.plot(x='Country', y='Environmental', kind='bar', title='% of GDP Spent on the Environment', color=colors)
enviro.set_ylabel('% of GDP')
# Out:
# Text(0, 0.5, '% of GDP')

# %% [markdown]
# According to OECD, environmental spending is spent on activities and facilities  for environmental protection. As the plot shows, countries spend within a small range between 0 and 0.90% of their GDP. The US spends the least which is about 0% of US GDP.  The year 2017 is also the year that President Trump announced US withdrawal from the Paris Climate Agreements. Norway spends the most which could be correlated to Norway's commitment to renewable energy.  Around 98% (2016) of Norway’s electricity comes from renewable sources in contrast to around 17% (2018) in the US. Overall, there is no significant difference in spending between the countries. Therefore, the amount governments spend on the environment does not seem to play a role in the difference in rated happiness.
#
# https://www.regjeringen.no/en/topics/energy/renewable-energy/renewable-energy-production-in-norway/id2343462/
# https://www.c2es.org/content/renewable-energy/#:~:text=Renewables%20made%20up%20more%20than,wind%20power%20(6.6%20percent).&text=Renewable%20ethanol%20and%20biodiesel%20transportation,from%207%20percent%20in%202006.

# %%
gen_service = main_df.plot(x='Country', y='General Services', kind='bar', title='% of GDP Spent on General Services', color=colors)
gen_service.set_ylabel('% of GDP')
# Out:
# Text(0, 0.5, '% of GDP')

# %% [markdown]
# According to the OECD, general public spending consists of spending within the federal government such as: executive and legislative organs, financial and fiscal affairs, external affairs, foreign economic aid, general services etc. The services seem to include only allocation for government affairs which are not made readily-available to the public nor does it affect citizens’ day-to-day lives. Citizens tend to give higher rated happiness in areas where they can directly see the services provided by the government. However, given that the allocation for general services only applies to spending for government affairs, the amount that the government spends on general services does not affect overall happiness rating.
#
# https://www.oecd.org/gov/48250728.pdf
# https://psmag.com/economics/new-research-suggests-that-government-spending-can-spread-happiness

# %%
health = main_df.plot(x='Country', y='Health', kind='bar', title='% of GDP Spent on Health', color=colors)
health.set_ylabel('% of GDP')
# Out:
# Text(0, 0.5, '% of GDP')

# %% [markdown]
# According to the OECD, health allocation includes services such as: medical products, appliance and equipment, outpatient services, hospital services, public health services, etc. According to the graph, the U.S. spends the most on health while Switzerland barely has any allocation towards health even though Switzerland is rated in the top 5 happiest countries. This is because “Switerzerland’s universal health care is highly decentralized”(Sturny). This means that the government has sent in policies so that private nonprofit companies will provide health insurance for all citizens with 100% coverage (universal health care). That is why Switzerland's allocation for health is so low even though they are rated as one of the best health care providers. Looking into this more, all countries (above) except for the U.S., provide universal health care. This means that not all U.S. citizens have access to health coverage and/or the insurance doesn’t cover all the health fees. With the information provided and from the graph above, health plays a very important factor in happiness rating, especially if that country has universal health care.
#
# https://www.vox.com/podcasts/2020/6/23/21298942/best-healthcare-germany-uk-france-the-ezra-klein-show
# https://www.commonwealthfund.org/international-health-policy-center/countries/switzerland

# %%
housing = main_df.plot(x='Country', y='Housing', kind='bar', title='% of GDP Spent on Housing', color=colors)
housing.set_ylabel('% of GDP')
# Out:
# Text(0, 0.5, '% of GDP')

# %% [markdown]
# The category of Housing expenditure can include funding towards affordable housing plans such as tax credits, rental vouchers. Larger projects for more public housing may be funded through this spending as well. Among the six countries, Norway allocates the most percentage of total GDP on Housing expenditure, reaching almost 0.8%. USA comes in second with a spending of just over 0.5%, followed very closely by Iceland. Norway provides housing allowance and lending services for lower income citizens. USA also has housing assistance programs.

# %%
public_safety = main_df.plot(x='Country', y='Public Safety', kind='bar', title='% of GDP Spent on Public Safety', color=colors)
public_safety.set_ylabel('% of GDP')
# Out:
# Text(0, 0.5, '% of GDP')

# %% [markdown]
# Public Safety expenditure can be categorized into police force funding, fire service, prison funding, and law court. The presence of forces that are meant to protect the public may increase citizens’ trust in the government in that in times of danger, there will be services that they can depend on. USA spent the most percentage of total GDP on Public Safety expenditure, amounting to nearly 2%. Switzerland comes in second at just over 1.5%. USA allocated the most of the public safety budget towards police funding.

# %%
rec = main_df.plot(x='Country', y='Recreation', kind='bar', title='% of GDP Spent on Recreation',color=colors)
rec.set_ylabel('% of GDP')
# Out:
# Text(0, 0.5, '% of GDP')

# %% [markdown]
# According to the OECD, spending on recreation consists of “sporting services; cultural services; broadcasting and publishing services; religious and other community services, etc…” Surprisingly, the United States spends the least in this category, but this may be because the largest aspect, which is sporting services, is typically spent through private companies rather than the government itself compared to other countries. Iceland on the other hand is a huge outlier, and this may be due to the fact that Iceland makes a lot of investments in after-school activities for teenagers to combat the substance abuse that many of them faced. Another aspect that they use recreational spending on is public sporting events and cultural performances that could keep their citizens engaged.
#
# https://icelandmag.is/article/state-spending-culture-higher-iceland-any-european-country-32-gdp#:~:text=Icelandic%20government%20expenditure%20on%20culture,more%20than%20the%20European%20Average

# %%
soc_prot = main_df.plot(x='Country', y='Social Protection', kind='bar', title='% of GDP Spent on Social Protection', color=colors)
soc_prot.set_ylabel('% of GDP')
# Out:
# Text(0, 0.5, '% of GDP')

# %% [markdown]
# Social Protection is defined as the benefits, direct provisions of goods and services, and tax breaks with social purposes. These programs are controlled by the central, state, or local governments and these benefits/provisions are often used to support low-income households, the elderly, disabled, sick, unemployed or young people. If you notice on the graph, although not an outlier, the United States spends the least when compared to the top 5 happiest countries and this may be due to the fact that there is a strong stigma surrounding social programs in the United States, and this topic is highly controversial, often getting rejected during times of voting. On the other hand, Finland is said to have the most advanced welfare systems in the world to increase the quality of life for Finnish citizens, and is said to be on a steady increase since 2009. They have Kela, which is the Social Insurance Institution of Finland that provides all citizens with social security, it especially goes to their elderly population, since they have to pay their retirement pensions and family benefits. Overall, Scandinavian countries are known to spend more on social services, rather than the United States which is represented in our graphs.

# %%
tot = main_df.plot(x='Country', y='Total', kind='bar', title='% of GDP Spent on Total Government Spending', color = colors)
tot.set_ylabel('% of GDP')
# Out:
# Text(0, 0.5, '% of GDP')

# %% [markdown]
# This stackplot is meant to be used to compare the total, while also considering the overall breakdown of the different categories within each country.

# %%
stack_plt = main_df[['Defence', 'Economic Affairs', 'Education', 'Environmental', 'General Services', 'Health', 'Housing', 'Public Safety', 'Recreation', 'Social Protection']].plot(kind='bar', stacked=True, figsize = (6,10))
stack_plt.legend(loc='center left', bbox_to_anchor=(1.0,0.5))
stack_plt.set_ylabel('% of GDP')
# Out:
# Text(0, 0.5, '% of GDP')

# %% [markdown]
# This stacked barplot represents only the specific categories we were able to find, and other GDP spending data, specifically private spending, is not taken into account. For example, in the health sector, Switzerland’s budget allocation is not represented through our data. On the other hand, this stacked barplot is able to give us an overview of spending among the different countries. By looking at this chart, you can see that all of the countries generally spend a large portion of their spending on Social Protection and Health, with General Services and Education following. The cause of this may stem from the fact that these categories involve financing basic needs, especially for those who are most vulnerable. In comparison, the U.S government spending differs most from the top 5 happiest countries for Defence, Public Safety, Recreation, and Social Protection, with Economic Affairs, Education, and Housing being the most similar.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# The data we need does not overstep any privacy or ethical requirements for this project and is openly available to the public since most countries need to publicize what they’re allocating money towards. Since we’re using data that is collected by government officials, it is reputable since they are the ones generating this data to begin with. Our one concern is that the public data is most likely skewed in some way to depict a country’s benevolence. To assure that our data can be replicable, we will document each step of our research process that we got our findings from. Our research also shouldn’t be expected to produce potential harm because we are specifically choosing to use data that is only available to the public through government sources that anyone can access. Although we are trying to see the impact of government spending on quality of life, there are also other nuanced factors that may affect a country’s quality of life that we don’t consider in our research, like education and data that concerns inequalities between different demographics. Although these are our concerns, we believe that our research will still be fully conducted within the ethical data science guidelines to generate accurate and unbiased results.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# **We fail to reject the null hypothesis**
#
# We do not have enough evidence to support the claim that the U.S. will be more of an outlier in the 10 government spending categories, even though the U.S. was ranked much lower than the other countries above. So in terms of our question, "How does government spending in the US differ from government spending in happier nations?", the U.S. government spending does not differ significantly from the happier nations. This could attributed to a couple limitations that we ran into(listed below).
#
# **Limitations**
# - For each category, we do not know the total allocation for each country - i.e. private spending not accounted for.
# - There are more spending that occurs than just government spending that influences happiness
#     - Policies (state, government) and their outcomes
# - Outliers might no be a proper way to measure differences in spending because countries could spend similarly in terms of categories, but not spend on the same resources.
#
# **What we'd do if we had more time**
# - Look into state/local spending/overall spending -> account for these categories as well
# - Looking into cost of living as well and how that impacts citizen's quality of life

# %% [markdown]
# # Team Contributions

# %% [markdown]
# We split the 10 government spending categories as so:
# - Defence - Kelly
# - Economic Affairs - Kelly
# - Education - Erika
# - Environmental - Erika
# - General Services - Theo
# - Health - Theo
# - Housing - Mylinh
# - Public Safety - Mylinh
# - Recreation - Bri
# - Social Protection - Bri
#
# Then, we each discussed our findings and collaborated putting together our conclusion, video, and ethics of our project.
